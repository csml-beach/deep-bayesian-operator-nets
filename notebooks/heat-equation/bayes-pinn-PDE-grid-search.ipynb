# %%
import torch
import random
import numpy as np
from numpy.ma.core import outer
from sys import stderr
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.pyplot import scatter, figure
from torch.utils.data import TensorDataset, DataLoader
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(4, 4)})

import warnings

warnings.filterwarnings('ignore')

seed = 42
batch_size = 100

np.random.seed(seed)
torch.manual_seed(seed)

class Experiment(nn.Module):
    def __init__(self):
        super(Experiment, self).__init__()

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
        print(self.device)

        self.optimizer = None
        self.train_loss_history = []
        self.w_ic = 1.5
        self.w_int = 1
        self.w_data = 1
        self.w_bc = 1.5
        self.w_param_std = 1.0
        self.numInputs = 2
        self.numParams = 2
        self.numOutputs = 1
        self.hidden_size = 25

        # Initialize history variables
        self.total_loss_history = []
        self.loss_ic_history = []
        self.loss_interior_history = []
        self.loss_data_history = []
        self.loss_bc_history = []
        self.loss_std_history = []

        self.t0 = torch.tensor([0.0], requires_grad=True).to(self.device)
        self.y0 = torch.tensor([1.0], requires_grad=True).to(self.device)

        # self.predicted_params = torch.zeros((self.numParams,1), requires_grad=True, device=self.device)
        self.predicted_params = torch.zeros((batch_size,2), requires_grad=True, device=self.device)

        # We only have 1 input feature
        self.b1 = nn.Linear(self.numInputs, self.hidden_size).to(self.device)
        self.b2 = nn.Linear(self.hidden_size, self.hidden_size).to(self.device)
        self.b3 = nn.Linear(self.hidden_size, self.numOutputs).to(self.device)

        self.t1 = nn.Linear(self.hidden_size, self.hidden_size).to(self.device)
        self.t2 = nn.Linear(self.hidden_size, self.hidden_size).to(self.device)
        self.t3 = nn.Linear(self.hidden_size, self.numParams).to(self.device)


    # make this static so that it can be called independently
    @staticmethod
    def exact_solution(t, x):
        return torch.exp(-t) * torch.sin(torch.pi * x)


    def forward(self, t, x):
        if not torch.is_tensor(t):
            t = torch.from_numpy(t).float().to(self.device)

        if not torch.is_tensor(x):
            x = torch.from_numpy(x).float().to(self.device)

        input = torch.cat((t, x), 1)
        h1 = torch.tanh(self.b1(input))
        h2 = torch.tanh(self.b2(h1))

        # prior_param_sample = torch.rand(1, 1, device=self.device).requires_grad_(True)
        prior_param_sample = torch.rand(batch_size, self.hidden_size , device=self.device).requires_grad_(True)

        t1 = torch.tanh(self.t1(prior_param_sample))
        t2 = torch.tanh(self.t2(t1))
        posterior_param_sample = self.t3(t2)
        self.predicted_params = posterior_param_sample

        y = self.b3(torch.multiply(t2, h2))

        return y


    # General formula to compute the n-th order derivative of y = f(x) with respect to x
    def compute_derivative(self, y, x, n):
        if n == 0:
            return y
        else:
            dy_dx = torch.autograd.grad(y, x, torch.ones_like(y, device= self.device),
                                        create_graph=True, retain_graph=True,
                                        allow_unused=True)[0]
        return self.compute_derivative(dy_dx, x, n - 1)



    def PDE_residual(self, t, x):
        y = self.forward(t, x)
        dy_dt = self.compute_derivative(y, t, 1)
        dy_dx = self.compute_derivative(y, x, 1)
        d2y_dx2 = self.compute_derivative(y, x, 2)

        residual =  dy_dt - torch.multiply(self.predicted_params[:,[0]], d2y_dx2) \
            + torch.exp(- self.predicted_params[:,[1]] * t) * (torch.sin(torch.tensor(np.pi) * x) - torch.tensor(np.pi) ** 2 * torch.sin(torch.tensor(np.pi) * x))
        return residual



    def loss_initial_condition(self, num_samples=100):
        t0 = self.t0 * torch.ones((num_samples, 1), device = self.device)
        x = 2*torch.rand((num_samples, 1), device=self.device).requires_grad_(True)  - 1.0
        y0_pred = self.forward(t0, x)
        y0_true = self.exact_solution(t0, x)
        loss_ic = torch.mean(torch.square(y0_true - y0_pred))
        return loss_ic


    def loss_boundary_condition(self, num_samples=100):
        x_low = -1
        x_high = 1
        xb_low   = x_low * torch.ones((num_samples, 1),  device = self.device)
        xb_high  = x_high * torch.ones((num_samples, 1), device = self.device)

        t = 2*torch.rand((num_samples, 1), device=self.device).requires_grad_(True) - 1.0

        yb_low = self.exact_solution(t, xb_low)
        yb_high = self.exact_solution(t, xb_high)

        yb_pred_low = self.forward(t, xb_low)
        yb_pred_high = self.forward(t, xb_high)

        loss_ic = torch.mean(torch.square(yb_pred_low - yb_low)) \
                + torch.mean(torch.square(yb_pred_high - yb_high))
        return loss_ic


    def compute_losses(self):
        loss_ic = self.loss_initial_condition()
        loss_interior = self.loss_interior()
        loss_data = self.loss_data()
        loss_bc = self.loss_boundary_condition()
        return loss_ic, loss_interior, loss_data, loss_bc


    def loss_data(self, num_samples=100):
        t_data, x_data, y_data = next(iter(train_loader))
        y_pred = self.forward(t_data, x_data)
        loss = torch.mean(torch.square(y_pred - y_data))
        return loss


    def loss_interior(self, num_samples=100):

        interior_t_samples = torch.rand((num_samples, 1),   device=self.device).requires_grad_(True)
        interior_x_samples = 2*torch.rand((num_samples, 1), device=self.device).requires_grad_(True)  - 1.0
        res = self.PDE_residual(interior_t_samples, interior_x_samples)
        loss_residual = torch.mean(torch.square(res))
        return loss_residual


    def sample_parameter_posterior(self, num_samples=100):
        prior_param_samples = torch.rand(num_samples, self.hidden_size, device=self.device).requires_grad_(True)
        t1 = torch.tanh(self.t1(prior_param_samples))
        t2 = torch.tanh(self.t2(t1))
        posterior_param_samples = self.t3(t2)
        return posterior_param_samples



    def update_predicted_params(self, posterior_samples):

        mean = torch.mean(posterior_samples, dim=0)  # Compute the mean along the first axis
        std = torch.std(posterior_samples, dim=0)    # Compute the standard deviation along the first axis

        self.predicted_params = posterior_samples
        self.mean_predicted_params = mean  # Store the mean
        self.std_params = std  # Attach the standard deviation as an attribute


    def closure(self):
        self.optimizer.zero_grad()
        loss_ic, loss_interior, loss_data, loss_bc = self.compute_losses()
        total_loss = self.w_ic * loss_ic \
                   + self.w_int * loss_interior \
                   + self.w_data * loss_data \
                   + self.w_bc * loss_bc

        # Sample the parameter posterior and update self.predicted_params and self.std_params
        posterior_samples = self.sample_parameter_posterior(num_samples=100)
        self.update_predicted_params(posterior_samples)

        # Add the (Log(std))**2 term to the loss with the specified weight
        self.log_std_squared_loss = self.w_param_std * torch.mean(torch.log(self.std_params)**2)
        total_loss += self.log_std_squared_loss

        total_loss.backward(retain_graph=True)
        return total_loss


    def train(self, epochs, optimizer='Adam', num_samples=100, **kwargs):
        if optimizer == 'Adam':
            self.optimizer = torch.optim.Adam(self.parameters(), **kwargs)

        elif optimizer == 'L-BFGS':
            self.optimizer = torch.optim.LBFGS(self.parameters(), **kwargs)

        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode='min', factor=0.1, patience=3, verbose=True)


        # Training loop
        out_of_range_count = 0
        log_interval = 100

        for epoch in range(epochs):
            self.optimizer.step(self.closure)

            if epoch % log_interval == 0:
                loss_ic, loss_interior, loss_data, loss_bc = self.compute_losses()
                total_loss = loss_ic + loss_interior + loss_data + loss_bc
                scheduler.step(total_loss)

                self.total_loss_history.append(total_loss.item())
                self.loss_ic_history.append(loss_ic.item())
                self.loss_interior_history.append(loss_interior.item())
                self.loss_data_history.append(loss_data.item())
                self.loss_bc_history.append(loss_bc.item())
                self.loss_std_history.append(self.log_std_squared_loss.item())

                # Check predicted param range
                param1 = self.mean_predicted_params[0].item()
                param2 = self.mean_predicted_params[1].item()

                if not (1.0 <= param1 <= 2.0 and 1.0 <= param2 <= 2.0):
                    out_of_range_count += 1
                else:
                    out_of_range_count = 0

                print(f'Epoch({optimizer}):{epoch},  Total Loss:{total_loss.item():.2f}  ' \
                    f'PDE Loss:{loss_interior.item():.2f}  ' \
                    f'BC Loss:{loss_bc.item():.2f}  ' \
                    f'IC Loss: {loss_ic.item():.2f}  ' \
                    f'Mean Predicted Param 1: {param1:.2f} ' \
                    f'Mean Predicted Param 2: {param2:.2f} ' \
                    f'Std Params:{self.std_params.detach().cpu().numpy()[0]:.2f}  ' \
                    f'Std Log Loss:{self.log_std_squared_loss.item():.2f}')

                if out_of_range_count >= 7:
                    print(f"Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for {out_of_range_count} logs.")
                    break

# %%
def sample_dataset(noise=0.1, numSamples=100, device='cpu'):
    t = torch.linspace(0, 1, numSamples, device=device) # Time domain
    x = torch.linspace(-1, 1, numSamples, device=device) # Space domain

    T, X   = torch.meshgrid(t, x) # Time-Space domain

    y_true = Experiment.exact_solution(T, X)
    T      = T.reshape(-1, 1) # Reshape to 2D to 1D
    X      = X.reshape(-1, 1) # Resahpe to 2D to 1D

    sample_mean = y_true.reshape(-1, 1)
    sample_var  = noise * torch.ones_like(sample_mean)
    Y_noisy     = torch.normal(sample_mean, sample_var)

    return T, X, Y_noisy


def create_train_test_datasets(device='cpu', batch_size = batch_size):
    t_train, x_train, y_train = sample_dataset(noise=0.01, numSamples=10, device=device)
    t_test, x_test, y_test = sample_dataset(noise=0.0, numSamples=100, device=device)

    fig = plt.figure()
    size = int(t_test.size(0)**0.5)


    plt.contourf(t_test.view(size, size).cpu().detach().numpy(),
                 x_test.view(size, size).cpu().detach().numpy(),
                 y_test.view(size, size).cpu().detach().numpy())
    plt.xlabel('t'); plt.ylabel('x');
    plt.colorbar()

    train_dataset = TensorDataset(t_train, x_train, y_train)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    test_dataset = TensorDataset(t_test, x_test, y_test)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

    return train_loader, test_loader


# sending only 10 samples due to mismatch
def plot_residuals(net, device, noise=0.0):
    t_test, x_test, y_test = sample_dataset(noise=noise, numSamples=100, device=device)

    # Define batch size
    batch_size = 100

    # Split the test dataset into batches
    t_batches = torch.split(t_test, batch_size)
    x_batches = torch.split(x_test, batch_size)

    # Initialize lists to store results
    mu_results = []
    t_results = []
    x_results = []

    # Iterate over batches
    for t_batch, x_batch in zip(t_batches, x_batches):
        # Call mu for each batch
        mu_batch = net.forward(t_batch, x_batch)
        mu_results.append(mu_batch)
        t_results.append(t_batch)
        x_results.append(x_batch)

    # Concatenate the results
    mu = torch.cat(mu_results)
    t_final = torch.cat(t_results)
    x_final = torch.cat(x_results)

    fig  = plt.figure(figsize=(6, 3))
    ax1  = plt.subplot(121)
    size = int(np.sqrt(x_test.size(0)))

    # Calculate the residuals (difference between predictions and ground truth)
    absDifference  = torch.abs(mu - y_test)
    residuals      = absDifference.view(size, size).cpu().detach().numpy()

    # Create a contour plot of the residuals
    cax = ax1.contourf(t_final.view(size, size).cpu().detach().numpy(),
                       x_final.view(size, size).cpu().detach().numpy(),
                       residuals)

    plt.colorbar(cax)
    plt.xlabel('t');plt.ylabel('x')
    plt.title("Residual")
    plt.show()


# sending only 10 samples due to mismatch
def make_plot(net, device):
    t_test, x_test, y_test = sample_dataset(noise=0.0, numSamples=100, device=device)

    # Define batch size
    batch_size = 100

    # Split the test dataset into batches
    t_batches = torch.split(t_test, batch_size)
    x_batches = torch.split(x_test, batch_size)

    # Initialize lists to store results
    mu_results = []
    t_results = []
    x_results = []

    # Iterate over batches
    for t_batch, x_batch in zip(t_batches, x_batches):
        # Call mu for each batch
        mu_batch = net.forward(t_batch, x_batch)
        mu_results.append(mu_batch)
        t_results.append(t_batch)
        x_results.append(x_batch)

    # Concatenate the results
    mu = torch.cat(mu_results)
    t_final = torch.cat(t_results)
    x_final = torch.cat(x_results)

    fig = plt.figure(figsize=(6, 3))
    ax1 = plt.subplot(121)
    ax2 = plt.subplot(122, sharex=ax1)
    size = int(np.sqrt(x_test.size(0)))

    ax1.contourf(t_final.view(size, size).cpu().detach().numpy(),
                 x_final.view(size, size).cpu().detach().numpy(),
                 mu.view(size, size).cpu().detach().numpy())

    ax1.set_xlabel('t')
    ax1.set_ylabel('x')
    ax1.set_title('Predicted Result')

    ax2.contourf(t_test.view(size, size).cpu().detach().numpy(),
                 x_test.view(size, size).cpu().detach().numpy(),
                 y_test.view(size, size).cpu().detach().numpy())

    ax2.set_xlabel('t')
    ax2.set_ylabel('x')
    ax2.set_title('Actual Result')

    plt.subplots_adjust(wspace=0.4)  # Adjust the width space between subplots
    plt.show()


def plot_loss_history(net):
    epochs = range(len(net.total_loss_history))

    plt.figure(figsize=(8, 6))
    plt.plot(epochs, net.total_loss_history, label='Total Loss')
    plt.plot(epochs, net.loss_ic_history, label='IC Loss')
    plt.plot(epochs, net.loss_interior_history, label='Interior Loss')
    plt.plot(epochs, net.loss_data_history, label='Data Loss')
    plt.plot(epochs, net.loss_bc_history, label='BC Loss')
    plt.plot(epochs, net.loss_std_history, label='STD Loss')

    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss Over Epochs')
    plt.legend()
    plt.show()


def plot_loss_history_log(net):
    epochs = range(len(net.total_loss_history))

    plt.figure(figsize=(8, 6))
    plt.semilogy(epochs, net.total_loss_history, label='Total Loss')
    plt.semilogy(epochs, net.loss_ic_history, label='IC Loss')
    plt.semilogy(epochs, net.loss_interior_history, label='Interior Loss')
    plt.semilogy(epochs, net.loss_data_history, label='Data Loss')
    plt.semilogy(epochs, net.loss_bc_history, label='BC Loss')
    plt.semilogy(epochs, net.loss_std_history, label='STD Loss')

    plt.xlabel('Epochs')
    plt.ylabel('Loss (log scale)')
    plt.title('Loss Over Epochs (log scale)')
    # plt.legend()
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
    # plt.savefig('log_loss_heat_4.png', dpi=400)
    plt.savefig('log_loss_heat_4.png', dpi=400, bbox_inches='tight')
    plt.show()

# %%
from itertools import product

def run_grid_search(net_class, weight_space, epochs=5000, lr=1e-2):
    best_loss = float('inf')
    best_weights = None
    all_results = []

    for w_ic, w_int, w_bc, w_data, w_param_std in product(*weight_space.values()):
        net = net_class().to(torch.device("cuda:0" if torch.cuda.is_available() else "cpu"))
        net.w_ic = w_ic
        net.w_int = w_int
        net.w_bc = w_bc
        net.w_data = w_data
        net.w_param_std = w_param_std

        print(f"Trying: w_ic={w_ic}, w_int={w_int}, w_bc={w_bc}, w_data={w_data}, w_param_std={w_param_std}")
        net.train(epochs, optimizer='Adam', lr=lr)

        final_loss = net.total_loss_history[-1]
        all_results.append((final_loss, (w_ic, w_int, w_bc, w_data, w_param_std)))

        if final_loss < best_loss:
            best_loss = final_loss
            best_weights = (w_ic, w_int, w_bc, w_data, w_param_std)

    print("\nBest weights found:")
    print(f"w_ic={best_weights[0]}, w_int={best_weights[1]}, w_bc={best_weights[2]}, w_data={best_weights[3]}, w_param_std={best_weights[4]}")
    return best_weights, all_results

# %%
net = Experiment()
net.to(net.device)
print("Params:", sum(p.numel() for p in net.parameters() if p.requires_grad))
# Out:
# cuda:0
# Params: 2103

# %%
train_loader, test_loader = create_train_test_datasets(device = net.device, batch_size=batch_size)

# %%
weight_space = {
    "w_ic": [1, 2, 3],
    "w_int": [0.5, 1],
    "w_bc": [0.5, 1],
    "w_data": [2, 4, 6],
    "w_param_std": [1]
}

torch.autograd.set_detect_anomaly(True)
best_weights, all_results = run_grid_search(Experiment, weight_space, epochs=5000)
# Out:
# cuda:0
# Trying: w_ic=1, w_int=0.5, w_bc=0.5, w_data=2, w_param_std=1
# Epoch(Adam):0,  Total Loss:30.54  PDE Loss:29.77  BC Loss:0.00  IC Loss: 0.58  Mean Predicted Param 1: -0.01 Mean Predicted Param 2: 0.01 Std Params:0.05  Std Log Loss:8.77
# Epoch(Adam):100,  Total Loss:0.51  PDE Loss:0.15  BC Loss:0.14  IC Loss: 0.14  Mean Predicted Param 1: 3.87 Mean Predicted Param 2: 3.91 Std Params:0.83  Std Log Loss:0.02
# Epoch(Adam):200,  Total Loss:0.51  PDE Loss:0.18  BC Loss:0.14  IC Loss: 0.11  Mean Predicted Param 1: 2.62 Mean Predicted Param 2: 4.29 Std Params:0.98  Std Log Loss:0.01
# Epoch(Adam):300,  Total Loss:0.41  PDE Loss:0.23  BC Loss:0.08  IC Loss: 0.06  Mean Predicted Param 1: 1.69 Mean Predicted Param 2: 3.86 Std Params:0.82  Std Log Loss:0.02
# Epoch(Adam):400,  Total Loss:0.50  PDE Loss:0.30  BC Loss:0.11  IC Loss: 0.04  Mean Predicted Param 1: 1.59 Mean Predicted Param 2: 3.00 Std Params:0.91  Std Log Loss:0.01
# Epoch(Adam):500,  Total Loss:0.17  PDE Loss:0.06  BC Loss:0.06  IC Loss: 0.02  Mean Predicted Param 1: 1.37 Mean Predicted Param 2: 2.59 Std Params:0.98  Std Log Loss:0.00
# Epoch(Adam):600,  Total Loss:0.29  PDE Loss:0.19  BC Loss:0.03  IC Loss: 0.04  Mean Predicted Param 1: 1.67 Mean Predicted Param 2: 2.40 Std Params:1.22  Std Log Loss:0.04
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=1, w_int=0.5, w_bc=0.5, w_data=4, w_param_std=1
# Epoch(Adam):0,  Total Loss:30.09  PDE Loss:29.46  BC Loss:0.00  IC Loss: 0.45  Mean Predicted Param 1: -0.07 Mean Predicted Param 2: 0.06 Std Params:0.04  Std Log Loss:10.79
# Epoch(Adam):100,  Total Loss:0.86  PDE Loss:0.14  BC Loss:0.24  IC Loss: 0.35  Mean Predicted Param 1: -6.27 Mean Predicted Param 2: 7.95 Std Params:0.84  Std Log Loss:0.07
# Epoch(Adam):200,  Total Loss:0.68  PDE Loss:0.08  BC Loss:0.18  IC Loss: 0.28  Mean Predicted Param 1: -8.21 Mean Predicted Param 2: 8.38 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):300,  Total Loss:0.63  PDE Loss:0.05  BC Loss:0.19  IC Loss: 0.26  Mean Predicted Param 1: -9.64 Mean Predicted Param 2: 8.47 Std Params:1.11  Std Log Loss:0.01
# Epoch(Adam):400,  Total Loss:0.64  PDE Loss:0.06  BC Loss:0.20  IC Loss: 0.25  Mean Predicted Param 1: -10.87 Mean Predicted Param 2: 8.68 Std Params:1.08  Std Log Loss:0.01
# Epoch(Adam):500,  Total Loss:0.65  PDE Loss:0.05  BC Loss:0.18  IC Loss: 0.29  Mean Predicted Param 1: -12.02 Mean Predicted Param 2: 8.99 Std Params:1.04  Std Log Loss:0.00
# Epoch(Adam):600,  Total Loss:0.57  PDE Loss:0.03  BC Loss:0.17  IC Loss: 0.24  Mean Predicted Param 1: -12.92 Mean Predicted Param 2: 9.29 Std Params:1.04  Std Log Loss:0.00
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=1, w_int=0.5, w_bc=0.5, w_data=6, w_param_std=1
# Epoch(Adam):0,  Total Loss:26.56  PDE Loss:25.90  BC Loss:0.01  IC Loss: 0.46  Mean Predicted Param 1: -0.03 Mean Predicted Param 2: 0.03 Std Params:0.04  Std Log Loss:9.93
# Epoch(Adam):100,  Total Loss:0.56  PDE Loss:0.13  BC Loss:0.20  IC Loss: 0.14  Mean Predicted Param 1: 3.25 Mean Predicted Param 2: 3.83 Std Params:0.92  Std Log Loss:0.00
# Epoch(Adam):200,  Total Loss:0.45  PDE Loss:0.22  BC Loss:0.13  IC Loss: 0.05  Mean Predicted Param 1: 1.75 Mean Predicted Param 2: 2.49 Std Params:0.74  Std Log Loss:0.05
# Epoch(Adam):300,  Total Loss:0.35  PDE Loss:0.25  BC Loss:0.04  IC Loss: 0.04  Mean Predicted Param 1: 1.46 Mean Predicted Param 2: 1.69 Std Params:0.72  Std Log Loss:0.05
# Epoch(Adam):400,  Total Loss:0.32  PDE Loss:0.25  BC Loss:0.02  IC Loss: 0.05  Mean Predicted Param 1: 1.48 Mean Predicted Param 2: 1.51 Std Params:0.79  Std Log Loss:0.03
# Epoch(Adam):500,  Total Loss:0.21  PDE Loss:0.14  BC Loss:0.03  IC Loss: 0.03  Mean Predicted Param 1: 1.19 Mean Predicted Param 2: 1.55 Std Params:0.82  Std Log Loss:0.02
# Epoch(Adam):600,  Total Loss:0.23  PDE Loss:0.16  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.43 Mean Predicted Param 2: 1.48 Std Params:1.01  Std Log Loss:0.00
# Epoch(Adam):700,  Total Loss:0.20  PDE Loss:0.15  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.38 Mean Predicted Param 2: 1.41 Std Params:1.01  Std Log Loss:0.00
# Epoch(Adam):800,  Total Loss:0.17  PDE Loss:0.10  BC Loss:0.02  IC Loss: 0.03  Mean Predicted Param 1: 1.33 Mean Predicted Param 2: 1.54 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):900,  Total Loss:0.26  PDE Loss:0.19  BC Loss:0.03  IC Loss: 0.02  Mean Predicted Param 1: 1.28 Mean Predicted Param 2: 1.46 Std Params:0.98  Std Log Loss:0.00
# Epoch(Adam):1000,  Total Loss:0.28  PDE Loss:0.23  BC Loss:0.01  IC Loss: 0.03  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.59 Std Params:0.73  Std Log Loss:0.05
# Epoch(Adam):1100,  Total Loss:0.30  PDE Loss:0.22  BC Loss:0.04  IC Loss: 0.03  Mean Predicted Param 1: 1.11 Mean Predicted Param 2: 1.73 Std Params:0.93  Std Log Loss:0.01
# Epoch(Adam):1200,  Total Loss:0.15  PDE Loss:0.11  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.02 Mean Predicted Param 2: 1.81 Std Params:0.78  Std Log Loss:0.06
# Epoch(Adam):1300,  Total Loss:0.18  PDE Loss:0.12  BC Loss:0.01  IC Loss: 0.03  Mean Predicted Param 1: 1.20 Mean Predicted Param 2: 1.61 Std Params:0.93  Std Log Loss:0.00
# Epoch(Adam):1400,  Total Loss:0.16  PDE Loss:0.11  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.16 Mean Predicted Param 2: 1.71 Std Params:0.82  Std Log Loss:0.02
# Epoch(Adam):1500,  Total Loss:0.21  PDE Loss:0.15  BC Loss:0.03  IC Loss: 0.02  Mean Predicted Param 1: 1.16 Mean Predicted Param 2: 1.86 Std Params:0.91  Std Log Loss:0.01
# Epoch(Adam):1600,  Total Loss:0.32  PDE Loss:0.28  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.54 Mean Predicted Param 2: 1.25 Std Params:1.24  Std Log Loss:0.04
# Epoch(Adam):1700,  Total Loss:0.12  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.03  Mean Predicted Param 1: 1.15 Mean Predicted Param 2: 1.64 Std Params:0.92  Std Log Loss:0.01
# Epoch(Adam):1800,  Total Loss:0.10  PDE Loss:0.06  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.48 Std Params:1.04  Std Log Loss:0.00
# Epoch(Adam):1900,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.29 Mean Predicted Param 2: 1.44 Std Params:1.11  Std Log Loss:0.01
# Epoch(Adam):2000,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.02 Mean Predicted Param 2: 1.72 Std Params:0.73  Std Log Loss:0.07
# Epoch(Adam):2100,  Total Loss:0.06  PDE Loss:0.03  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.08 Mean Predicted Param 2: 1.58 Std Params:0.72  Std Log Loss:0.07
# Epoch(Adam):2200,  Total Loss:0.08  PDE Loss:0.03  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.51 Std Params:0.96  Std Log Loss:0.00
# Epoch(Adam):2300,  Total Loss:0.09  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.16 Mean Predicted Param 2: 1.52 Std Params:0.88  Std Log Loss:0.01
# Epoch(Adam):2400,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.26 Mean Predicted Param 2: 1.44 Std Params:1.04  Std Log Loss:0.00
# Epoch(Adam):2500,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.14 Mean Predicted Param 2: 1.57 Std Params:0.91  Std Log Loss:0.01
# Epoch(Adam):2600,  Total Loss:0.10  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.23 Mean Predicted Param 2: 1.49 Std Params:1.01  Std Log Loss:0.00
# Epoch(Adam):2700,  Total Loss:0.09  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.54 Std Params:0.84  Std Log Loss:0.02
# Epoch(Adam):2800,  Total Loss:0.10  PDE Loss:0.04  BC Loss:0.03  IC Loss: 0.02  Mean Predicted Param 1: 1.39 Mean Predicted Param 2: 1.29 Std Params:1.10  Std Log Loss:0.01
# Epoch(Adam):2900,  Total Loss:0.10  PDE Loss:0.05  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.56 Std Params:0.86  Std Log Loss:0.02
# Epoch(Adam):3000,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.53 Std Params:0.92  Std Log Loss:0.01
# Epoch(Adam):3100,  Total Loss:0.08  PDE Loss:0.03  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.09 Mean Predicted Param 2: 1.58 Std Params:0.82  Std Log Loss:0.03
# Epoch(Adam):3200,  Total Loss:0.06  PDE Loss:0.02  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.09 Mean Predicted Param 2: 1.59 Std Params:0.84  Std Log Loss:0.03
# Epoch(Adam):3300,  Total Loss:0.08  PDE Loss:0.03  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.52 Std Params:0.94  Std Log Loss:0.00
# Epoch(Adam):3400,  Total Loss:0.08  PDE Loss:0.03  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.09 Mean Predicted Param 2: 1.57 Std Params:0.80  Std Log Loss:0.04
# Epoch(Adam):3500,  Total Loss:0.11  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.28 Mean Predicted Param 2: 1.39 Std Params:1.01  Std Log Loss:0.00
# Epoch(Adam):3600,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.14 Mean Predicted Param 2: 1.55 Std Params:0.89  Std Log Loss:0.01
# Epoch(Adam):3700,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.48 Std Params:0.98  Std Log Loss:0.00
# Epoch(Adam):3800,  Total Loss:0.08  PDE Loss:0.02  BC Loss:0.02  IC Loss: 0.03  Mean Predicted Param 1: 1.05 Mean Predicted Param 2: 1.59 Std Params:0.69  Std Log Loss:0.09
# Epoch(Adam):3900,  Total Loss:0.09  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.20 Mean Predicted Param 2: 1.52 Std Params:1.00  Std Log Loss:0.00
# Epoch(Adam):4000,  Total Loss:0.08  PDE Loss:0.03  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.16 Mean Predicted Param 2: 1.56 Std Params:0.96  Std Log Loss:0.00
# Epoch(Adam):4100,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.48 Std Params:0.85  Std Log Loss:0.02
# Epoch(Adam):4200,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.32 Mean Predicted Param 2: 1.37 Std Params:1.07  Std Log Loss:0.00
# Epoch(Adam):4300,  Total Loss:0.08  PDE Loss:0.02  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.01 Mean Predicted Param 2: 1.66 Std Params:0.68  Std Log Loss:0.10
# Epoch(Adam):4400,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.15 Mean Predicted Param 2: 1.47 Std Params:0.81  Std Log Loss:0.03
# Epoch(Adam):4500,  Total Loss:0.08  PDE Loss:0.03  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.20 Mean Predicted Param 2: 1.49 Std Params:0.95  Std Log Loss:0.00
# Epoch(Adam):4600,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.07 Mean Predicted Param 2: 1.66 Std Params:0.86  Std Log Loss:0.02
# Epoch(Adam):4700,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.20 Mean Predicted Param 2: 1.51 Std Params:0.99  Std Log Loss:0.00
# Epoch(Adam):4800,  Total Loss:0.09  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.49 Std Params:0.87  Std Log Loss:0.01
# Epoch(Adam):4900,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.16 Mean Predicted Param 2: 1.55 Std Params:0.90  Std Log Loss:0.01
# cuda:0
# Trying: w_ic=1, w_int=0.5, w_bc=1, w_data=2, w_param_std=1
# Epoch(Adam):0,  Total Loss:31.88  PDE Loss:30.93  BC Loss:0.06  IC Loss: 0.66  Mean Predicted Param 1: 0.17 Mean Predicted Param 2: -0.09 Std Params:0.04  Std Log Loss:10.88
# Epoch(Adam):100,  Total Loss:1.01  PDE Loss:0.37  BC Loss:0.16  IC Loss: 0.35  Mean Predicted Param 1: -6.58 Mean Predicted Param 2: 7.12 Std Params:1.05  Std Log Loss:0.01
# Epoch(Adam):200,  Total Loss:0.71  PDE Loss:0.14  BC Loss:0.09  IC Loss: 0.32  Mean Predicted Param 1: -8.44 Mean Predicted Param 2: 7.49 Std Params:0.96  Std Log Loss:0.00
# Epoch(Adam):300,  Total Loss:0.59  PDE Loss:0.04  BC Loss:0.12  IC Loss: 0.28  Mean Predicted Param 1: -9.89 Mean Predicted Param 2: 7.67 Std Params:1.05  Std Log Loss:0.00
# Epoch(Adam):400,  Total Loss:0.53  PDE Loss:0.04  BC Loss:0.08  IC Loss: 0.27  Mean Predicted Param 1: -11.45 Mean Predicted Param 2: 8.07 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):500,  Total Loss:0.64  PDE Loss:0.11  BC Loss:0.12  IC Loss: 0.26  Mean Predicted Param 1: -12.18 Mean Predicted Param 2: 7.97 Std Params:0.96  Std Log Loss:0.00
# Epoch(Adam):600,  Total Loss:0.55  PDE Loss:0.04  BC Loss:0.11  IC Loss: 0.26  Mean Predicted Param 1: -13.58 Mean Predicted Param 2: 8.48 Std Params:0.99  Std Log Loss:0.00
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=1, w_int=0.5, w_bc=1, w_data=4, w_param_std=1
# Epoch(Adam):0,  Total Loss:24.03  PDE Loss:23.36  BC Loss:0.01  IC Loss: 0.47  Mean Predicted Param 1: 0.08 Mean Predicted Param 2: 0.20 Std Params:0.05  Std Log Loss:9.68
# Epoch(Adam):100,  Total Loss:0.60  PDE Loss:0.22  BC Loss:0.11  IC Loss: 0.18  Mean Predicted Param 1: 4.32 Mean Predicted Param 2: 6.42 Std Params:0.76  Std Log Loss:0.08
# Epoch(Adam):200,  Total Loss:0.42  PDE Loss:0.15  BC Loss:0.10  IC Loss: 0.08  Mean Predicted Param 1: 2.90 Mean Predicted Param 2: 5.09 Std Params:0.83  Std Log Loss:0.02
# Epoch(Adam):300,  Total Loss:0.38  PDE Loss:0.20  BC Loss:0.07  IC Loss: 0.04  Mean Predicted Param 1: 1.85 Mean Predicted Param 2: 4.28 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):400,  Total Loss:0.26  PDE Loss:0.16  BC Loss:0.01  IC Loss: 0.04  Mean Predicted Param 1: 1.50 Mean Predicted Param 2: 3.15 Std Params:0.78  Std Log Loss:0.03
# Epoch(Adam):500,  Total Loss:0.32  PDE Loss:0.24  BC Loss:0.03  IC Loss: 0.03  Mean Predicted Param 1: 1.35 Mean Predicted Param 2: 2.67 Std Params:0.99  Std Log Loss:0.00
# Epoch(Adam):600,  Total Loss:0.19  PDE Loss:0.13  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.28 Mean Predicted Param 2: 2.11 Std Params:0.89  Std Log Loss:0.01
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=1, w_int=0.5, w_bc=1, w_data=6, w_param_std=1
# Epoch(Adam):0,  Total Loss:30.39  PDE Loss:29.69  BC Loss:0.00  IC Loss: 0.52  Mean Predicted Param 1: -0.03 Mean Predicted Param 2: -0.04 Std Params:0.06  Std Log Loss:8.33
# Epoch(Adam):100,  Total Loss:0.66  PDE Loss:0.31  BC Loss:0.12  IC Loss: 0.14  Mean Predicted Param 1: 3.03 Mean Predicted Param 2: 4.14 Std Params:0.84  Std Log Loss:0.02
# Epoch(Adam):200,  Total Loss:0.46  PDE Loss:0.31  BC Loss:0.06  IC Loss: 0.06  Mean Predicted Param 1: 1.62 Mean Predicted Param 2: 2.63 Std Params:0.71  Std Log Loss:0.06
# Epoch(Adam):300,  Total Loss:0.52  PDE Loss:0.44  BC Loss:0.02  IC Loss: 0.04  Mean Predicted Param 1: 1.37 Mean Predicted Param 2: 1.63 Std Params:0.82  Std Log Loss:0.02
# Epoch(Adam):400,  Total Loss:0.20  PDE Loss:0.15  BC Loss:0.01  IC Loss: 0.03  Mean Predicted Param 1: 1.34 Mean Predicted Param 2: 1.42 Std Params:0.83  Std Log Loss:0.02
# Epoch(Adam):500,  Total Loss:0.18  PDE Loss:0.12  BC Loss:0.02  IC Loss: 0.03  Mean Predicted Param 1: 1.34 Mean Predicted Param 2: 1.32 Std Params:0.86  Std Log Loss:0.01
# Epoch(Adam):600,  Total Loss:0.27  PDE Loss:0.17  BC Loss:0.04  IC Loss: 0.04  Mean Predicted Param 1: 1.01 Mean Predicted Param 2: 1.89 Std Params:0.72  Std Log Loss:0.06
# Epoch(Adam):700,  Total Loss:0.33  PDE Loss:0.28  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.09 Mean Predicted Param 2: 1.74 Std Params:0.80  Std Log Loss:0.03
# Epoch(Adam):800,  Total Loss:0.20  PDE Loss:0.15  BC Loss:0.02  IC Loss: 0.03  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.68 Std Params:0.68  Std Log Loss:0.08
# Epoch(Adam):900,  Total Loss:0.20  PDE Loss:0.15  BC Loss:0.02  IC Loss: 0.03  Mean Predicted Param 1: 1.30 Mean Predicted Param 2: 1.57 Std Params:1.03  Std Log Loss:0.00
# Epoch(Adam):1000,  Total Loss:0.19  PDE Loss:0.15  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.45 Mean Predicted Param 2: 1.32 Std Params:1.16  Std Log Loss:0.01
# Epoch(Adam):1100,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.25 Mean Predicted Param 2: 1.48 Std Params:1.01  Std Log Loss:0.00
# Epoch(Adam):1200,  Total Loss:0.17  PDE Loss:0.13  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.05 Mean Predicted Param 2: 1.65 Std Params:0.71  Std Log Loss:0.08
# Epoch(Adam):1300,  Total Loss:0.14  PDE Loss:0.10  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.25 Mean Predicted Param 2: 1.43 Std Params:0.93  Std Log Loss:0.00
# Epoch(Adam):1400,  Total Loss:0.13  PDE Loss:0.08  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.11 Mean Predicted Param 2: 1.62 Std Params:0.84  Std Log Loss:0.03
# Epoch(Adam):1500,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.28 Mean Predicted Param 2: 1.38 Std Params:1.00  Std Log Loss:0.00
# Epoch(Adam):1600,  Total Loss:0.16  PDE Loss:0.12  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.29 Mean Predicted Param 2: 1.39 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):1700,  Total Loss:0.11  PDE Loss:0.08  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.23 Mean Predicted Param 2: 1.45 Std Params:0.99  Std Log Loss:0.00
# Epoch(Adam):1800,  Total Loss:0.08  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.08 Mean Predicted Param 2: 1.72 Std Params:0.88  Std Log Loss:0.01
# Epoch(Adam):1900,  Total Loss:0.12  PDE Loss:0.07  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.26 Mean Predicted Param 2: 1.45 Std Params:1.02  Std Log Loss:0.00
# Epoch(Adam):2000,  Total Loss:0.19  PDE Loss:0.15  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.06 Mean Predicted Param 2: 1.61 Std Params:0.78  Std Log Loss:0.04
# Epoch(Adam):2100,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.08 Mean Predicted Param 2: 1.56 Std Params:0.72  Std Log Loss:0.07
# Epoch(Adam):2200,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.26 Mean Predicted Param 2: 1.38 Std Params:0.95  Std Log Loss:0.00
# Epoch(Adam):2300,  Total Loss:0.11  PDE Loss:0.06  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.11 Mean Predicted Param 2: 1.58 Std Params:0.80  Std Log Loss:0.03
# Epoch(Adam):2400,  Total Loss:0.13  PDE Loss:0.09  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.26 Mean Predicted Param 2: 1.42 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):2500,  Total Loss:0.13  PDE Loss:0.08  BC Loss:0.01  IC Loss: 0.03  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.50 Std Params:0.81  Std Log Loss:0.04
# Epoch(Adam):2600,  Total Loss:0.11  PDE Loss:0.08  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.20 Mean Predicted Param 2: 1.50 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):2700,  Total Loss:0.09  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.07 Mean Predicted Param 2: 1.62 Std Params:0.80  Std Log Loss:0.04
# Epoch(Adam):2800,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.19 Mean Predicted Param 2: 1.49 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):2900,  Total Loss:0.08  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.23 Mean Predicted Param 2: 1.49 Std Params:0.96  Std Log Loss:0.00
# Epoch(Adam):3000,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.11 Mean Predicted Param 2: 1.58 Std Params:0.86  Std Log Loss:0.02
# Epoch(Adam):3100,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.40 Std Params:0.92  Std Log Loss:0.00
# Epoch(Adam):3200,  Total Loss:0.11  PDE Loss:0.06  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.47 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):3300,  Total Loss:0.16  PDE Loss:0.12  BC Loss:0.01  IC Loss: 0.03  Mean Predicted Param 1: 1.25 Mean Predicted Param 2: 1.32 Std Params:0.85  Std Log Loss:0.02
# Epoch(Adam):3400,  Total Loss:0.07  PDE Loss:0.03  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.41 Mean Predicted Param 2: 1.28 Std Params:1.12  Std Log Loss:0.01
# Epoch(Adam):3500,  Total Loss:0.12  PDE Loss:0.08  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.30 Mean Predicted Param 2: 1.38 Std Params:1.07  Std Log Loss:0.00
# Epoch(Adam):3600,  Total Loss:0.12  PDE Loss:0.07  BC Loss:0.01  IC Loss: 0.03  Mean Predicted Param 1: 1.25 Mean Predicted Param 2: 1.47 Std Params:1.09  Std Log Loss:0.00
# Epoch(Adam):3700,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.03  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.51 Std Params:0.73  Std Log Loss:0.05
# Epoch(Adam):3800,  Total Loss:0.10  PDE Loss:0.06  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.14 Mean Predicted Param 2: 1.52 Std Params:0.83  Std Log Loss:0.02
# Epoch(Adam):3900,  Total Loss:0.15  PDE Loss:0.10  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.08 Mean Predicted Param 2: 1.58 Std Params:0.78  Std Log Loss:0.05
# Epoch(Adam):4000,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.23 Mean Predicted Param 2: 1.43 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):4100,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.03 Mean Predicted Param 2: 1.57 Std Params:0.62  Std Log Loss:0.14
# Epoch(Adam):4200,  Total Loss:0.10  PDE Loss:0.06  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.06 Mean Predicted Param 2: 1.61 Std Params:0.74  Std Log Loss:0.06
# Epoch(Adam):4300,  Total Loss:0.12  PDE Loss:0.09  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.38 Mean Predicted Param 2: 1.27 Std Params:1.10  Std Log Loss:0.00
# Epoch(Adam):4400,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.57 Std Params:0.84  Std Log Loss:0.02
# Epoch(Adam):4500,  Total Loss:0.10  PDE Loss:0.06  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.62 Std Params:0.87  Std Log Loss:0.01
# Epoch(Adam):4600,  Total Loss:0.12  PDE Loss:0.08  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.11 Mean Predicted Param 2: 1.55 Std Params:0.72  Std Log Loss:0.06
# Epoch(Adam):4700,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.40 Mean Predicted Param 2: 1.30 Std Params:1.11  Std Log Loss:0.01
# Epoch(Adam):4800,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.31 Mean Predicted Param 2: 1.33 Std Params:1.02  Std Log Loss:0.00
# Epoch(Adam):4900,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.41 Std Params:0.92  Std Log Loss:0.01
# cuda:0
# Trying: w_ic=1, w_int=1, w_bc=0.5, w_data=2, w_param_std=1
# Epoch(Adam):0,  Total Loss:32.43  PDE Loss:31.66  BC Loss:0.02  IC Loss: 0.54  Mean Predicted Param 1: -0.11 Mean Predicted Param 2: -0.16 Std Params:0.04  Std Log Loss:9.62
# Epoch(Adam):100,  Total Loss:0.88  PDE Loss:0.11  BC Loss:0.26  IC Loss: 0.38  Mean Predicted Param 1: -6.29 Mean Predicted Param 2: 5.87 Std Params:0.86  Std Log Loss:0.06
# Epoch(Adam):200,  Total Loss:0.72  PDE Loss:0.02  BC Loss:0.26  IC Loss: 0.31  Mean Predicted Param 1: -7.70 Mean Predicted Param 2: 6.06 Std Params:1.00  Std Log Loss:0.00
# Epoch(Adam):300,  Total Loss:0.67  PDE Loss:0.02  BC Loss:0.19  IC Loss: 0.32  Mean Predicted Param 1: -8.94 Mean Predicted Param 2: 6.47 Std Params:0.99  Std Log Loss:0.00
# Epoch(Adam):400,  Total Loss:0.63  PDE Loss:0.01  BC Loss:0.22  IC Loss: 0.27  Mean Predicted Param 1: -9.86 Mean Predicted Param 2: 6.69 Std Params:1.05  Std Log Loss:0.00
# Epoch(Adam):500,  Total Loss:0.66  PDE Loss:0.02  BC Loss:0.20  IC Loss: 0.31  Mean Predicted Param 1: -10.29 Mean Predicted Param 2: 6.73 Std Params:1.12  Std Log Loss:0.01
# Epoch(Adam):600,  Total Loss:0.60  PDE Loss:0.02  BC Loss:0.16  IC Loss: 0.28  Mean Predicted Param 1: -11.33 Mean Predicted Param 2: 7.29 Std Params:0.94  Std Log Loss:0.00
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=1, w_int=1, w_bc=0.5, w_data=4, w_param_std=1
# Epoch(Adam):0,  Total Loss:44.28  PDE Loss:43.58  BC Loss:0.01  IC Loss: 0.49  Mean Predicted Param 1: 0.18 Mean Predicted Param 2: -0.31 Std Params:0.04  Std Log Loss:9.88
# Epoch(Adam):100,  Total Loss:1.03  PDE Loss:0.50  BC Loss:0.27  IC Loss: 0.16  Mean Predicted Param 1: 4.57 Mean Predicted Param 2: 5.14 Std Params:0.87  Std Log Loss:0.03
# Epoch(Adam):200,  Total Loss:0.53  PDE Loss:0.16  BC Loss:0.15  IC Loss: 0.12  Mean Predicted Param 1: 3.84 Mean Predicted Param 2: 4.76 Std Params:0.86  Std Log Loss:0.02
# Epoch(Adam):300,  Total Loss:0.40  PDE Loss:0.08  BC Loss:0.12  IC Loss: 0.10  Mean Predicted Param 1: 2.89 Mean Predicted Param 2: 4.45 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):400,  Total Loss:0.29  PDE Loss:0.10  BC Loss:0.10  IC Loss: 0.04  Mean Predicted Param 1: 2.03 Mean Predicted Param 2: 3.85 Std Params:0.88  Std Log Loss:0.01
# Epoch(Adam):500,  Total Loss:0.26  PDE Loss:0.05  BC Loss:0.10  IC Loss: 0.05  Mean Predicted Param 1: 1.68 Mean Predicted Param 2: 3.85 Std Params:0.81  Std Log Loss:0.02
# Epoch(Adam):600,  Total Loss:0.27  PDE Loss:0.07  BC Loss:0.11  IC Loss: 0.04  Mean Predicted Param 1: 1.45 Mean Predicted Param 2: 3.45 Std Params:0.77  Std Log Loss:0.04
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=1, w_int=1, w_bc=0.5, w_data=6, w_param_std=1
# Epoch(Adam):0,  Total Loss:30.21  PDE Loss:29.35  BC Loss:0.01  IC Loss: 0.63  Mean Predicted Param 1: 0.31 Mean Predicted Param 2: -0.04 Std Params:0.07  Std Log Loss:7.98
# Epoch(Adam):100,  Total Loss:0.73  PDE Loss:0.23  BC Loss:0.24  IC Loss: 0.16  Mean Predicted Param 1: 5.06 Mean Predicted Param 2: 5.83 Std Params:0.84  Std Log Loss:0.04
# Epoch(Adam):200,  Total Loss:0.72  PDE Loss:0.23  BC Loss:0.23  IC Loss: 0.15  Mean Predicted Param 1: 4.92 Mean Predicted Param 2: 5.72 Std Params:0.86  Std Log Loss:0.01
# Epoch(Adam):300,  Total Loss:0.50  PDE Loss:0.09  BC Loss:0.19  IC Loss: 0.12  Mean Predicted Param 1: 3.68 Mean Predicted Param 2: 4.79 Std Params:0.82  Std Log Loss:0.03
# Epoch(Adam):400,  Total Loss:0.45  PDE Loss:0.15  BC Loss:0.13  IC Loss: 0.09  Mean Predicted Param 1: 2.39 Mean Predicted Param 2: 4.11 Std Params:0.87  Std Log Loss:0.01
# Epoch(Adam):500,  Total Loss:0.28  PDE Loss:0.14  BC Loss:0.06  IC Loss: 0.03  Mean Predicted Param 1: 1.39 Mean Predicted Param 2: 3.23 Std Params:0.71  Std Log Loss:0.07
# Epoch(Adam):600,  Total Loss:0.28  PDE Loss:0.16  BC Loss:0.07  IC Loss: 0.03  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 2.56 Std Params:0.63  Std Log Loss:0.14
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=1, w_int=1, w_bc=1, w_data=2, w_param_std=1
# Epoch(Adam):0,  Total Loss:24.43  PDE Loss:23.63  BC Loss:0.05  IC Loss: 0.52  Mean Predicted Param 1: 0.18 Mean Predicted Param 2: 0.23 Std Params:0.05  Std Log Loss:8.97
# Epoch(Adam):100,  Total Loss:0.65  PDE Loss:0.27  BC Loss:0.08  IC Loss: 0.17  Mean Predicted Param 1: 5.15 Mean Predicted Param 2: 5.96 Std Params:1.00  Std Log Loss:0.00
# Epoch(Adam):200,  Total Loss:0.43  PDE Loss:0.06  BC Loss:0.08  IC Loss: 0.17  Mean Predicted Param 1: 4.39 Mean Predicted Param 2: 5.12 Std Params:0.94  Std Log Loss:0.00
# Epoch(Adam):300,  Total Loss:0.39  PDE Loss:0.05  BC Loss:0.07  IC Loss: 0.15  Mean Predicted Param 1: 3.52 Mean Predicted Param 2: 5.06 Std Params:0.94  Std Log Loss:0.00
# Epoch(Adam):400,  Total Loss:0.41  PDE Loss:0.11  BC Loss:0.08  IC Loss: 0.12  Mean Predicted Param 1: 2.89 Mean Predicted Param 2: 4.91 Std Params:0.91  Std Log Loss:0.00
# Epoch(Adam):500,  Total Loss:0.31  PDE Loss:0.11  BC Loss:0.05  IC Loss: 0.07  Mean Predicted Param 1: 2.08 Mean Predicted Param 2: 4.62 Std Params:0.79  Std Log Loss:0.03
# Epoch(Adam):600,  Total Loss:0.23  PDE Loss:0.04  BC Loss:0.05  IC Loss: 0.07  Mean Predicted Param 1: 2.19 Mean Predicted Param 2: 4.70 Std Params:0.96  Std Log Loss:0.00
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=1, w_int=1, w_bc=1, w_data=4, w_param_std=1
# Epoch(Adam):0,  Total Loss:35.06  PDE Loss:34.31  BC Loss:0.01  IC Loss: 0.54  Mean Predicted Param 1: 0.13 Mean Predicted Param 2: -0.05 Std Params:0.05  Std Log Loss:10.29
# Epoch(Adam):100,  Total Loss:0.79  PDE Loss:0.34  BC Loss:0.13  IC Loss: 0.20  Mean Predicted Param 1: 4.83 Mean Predicted Param 2: 5.67 Std Params:0.92  Std Log Loss:0.01
# Epoch(Adam):200,  Total Loss:0.47  PDE Loss:0.12  BC Loss:0.10  IC Loss: 0.14  Mean Predicted Param 1: 4.42 Mean Predicted Param 2: 5.11 Std Params:0.88  Std Log Loss:0.01
# Epoch(Adam):300,  Total Loss:0.36  PDE Loss:0.08  BC Loss:0.08  IC Loss: 0.10  Mean Predicted Param 1: 3.10 Mean Predicted Param 2: 4.07 Std Params:0.81  Std Log Loss:0.03
# Epoch(Adam):400,  Total Loss:0.30  PDE Loss:0.10  BC Loss:0.07  IC Loss: 0.07  Mean Predicted Param 1: 2.26 Mean Predicted Param 2: 4.04 Std Params:1.03  Std Log Loss:0.01
# Epoch(Adam):500,  Total Loss:0.17  PDE Loss:0.06  BC Loss:0.04  IC Loss: 0.04  Mean Predicted Param 1: 1.43 Mean Predicted Param 2: 3.05 Std Params:0.76  Std Log Loss:0.04
# Epoch(Adam):600,  Total Loss:0.19  PDE Loss:0.09  BC Loss:0.05  IC Loss: 0.03  Mean Predicted Param 1: 1.48 Mean Predicted Param 2: 2.52 Std Params:0.84  Std Log Loss:0.02
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=1, w_int=1, w_bc=1, w_data=6, w_param_std=1
# Epoch(Adam):0,  Total Loss:29.17  PDE Loss:28.47  BC Loss:0.01  IC Loss: 0.50  Mean Predicted Param 1: -0.19 Mean Predicted Param 2: -0.01 Std Params:0.06  Std Log Loss:9.10
# Epoch(Adam):100,  Total Loss:0.78  PDE Loss:0.34  BC Loss:0.15  IC Loss: 0.17  Mean Predicted Param 1: 5.08 Mean Predicted Param 2: 5.36 Std Params:0.80  Std Log Loss:0.06
# Epoch(Adam):200,  Total Loss:0.54  PDE Loss:0.15  BC Loss:0.14  IC Loss: 0.16  Mean Predicted Param 1: 4.62 Mean Predicted Param 2: 4.07 Std Params:1.02  Std Log Loss:0.00
# Epoch(Adam):300,  Total Loss:0.39  PDE Loss:0.13  BC Loss:0.07  IC Loss: 0.11  Mean Predicted Param 1: 2.64 Mean Predicted Param 2: 2.70 Std Params:0.82  Std Log Loss:0.03
# Epoch(Adam):400,  Total Loss:0.24  PDE Loss:0.11  BC Loss:0.05  IC Loss: 0.04  Mean Predicted Param 1: 1.52 Mean Predicted Param 2: 2.20 Std Params:0.72  Std Log Loss:0.07
# Epoch(Adam):500,  Total Loss:0.18  PDE Loss:0.08  BC Loss:0.05  IC Loss: 0.03  Mean Predicted Param 1: 1.31 Mean Predicted Param 2: 2.04 Std Params:0.75  Std Log Loss:0.06
# Epoch(Adam):600,  Total Loss:0.14  PDE Loss:0.05  BC Loss:0.04  IC Loss: 0.03  Mean Predicted Param 1: 1.26 Mean Predicted Param 2: 1.85 Std Params:0.69  Std Log Loss:0.09
# Epoch(Adam):700,  Total Loss:0.15  PDE Loss:0.09  BC Loss:0.03  IC Loss: 0.02  Mean Predicted Param 1: 1.38 Mean Predicted Param 2: 1.79 Std Params:0.89  Std Log Loss:0.01
# Epoch(Adam):800,  Total Loss:0.14  PDE Loss:0.08  BC Loss:0.02  IC Loss: 0.03  Mean Predicted Param 1: 1.21 Mean Predicted Param 2: 1.66 Std Params:0.73  Std Log Loss:0.08
# Epoch(Adam):900,  Total Loss:0.11  PDE Loss:0.08  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.55 Std Params:0.77  Std Log Loss:0.05
# Epoch(Adam):1000,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.25 Mean Predicted Param 2: 1.58 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):1100,  Total Loss:0.10  PDE Loss:0.05  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.14 Mean Predicted Param 2: 1.46 Std Params:0.60  Std Log Loss:0.21
# Epoch(Adam):1200,  Total Loss:0.13  PDE Loss:0.07  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.51 Mean Predicted Param 2: 1.77 Std Params:1.20  Std Log Loss:0.04
# Epoch(Adam):1300,  Total Loss:0.23  PDE Loss:0.14  BC Loss:0.02  IC Loss: 0.05  Mean Predicted Param 1: 1.31 Mean Predicted Param 2: 1.67 Std Params:0.71  Std Log Loss:0.07
# Epoch(Adam):1400,  Total Loss:0.09  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.35 Mean Predicted Param 2: 1.64 Std Params:1.03  Std Log Loss:0.00
# Epoch(Adam):1500,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.28 Mean Predicted Param 2: 1.58 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):1600,  Total Loss:0.05  PDE Loss:0.02  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.36 Mean Predicted Param 2: 1.64 Std Params:1.12  Std Log Loss:0.02
# Epoch(Adam):1700,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.15 Mean Predicted Param 2: 1.41 Std Params:0.77  Std Log Loss:0.06
# Epoch(Adam):1800,  Total Loss:0.08  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.03  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.50 Std Params:0.86  Std Log Loss:0.02
# Epoch(Adam):1900,  Total Loss:0.07  PDE Loss:0.02  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.36 Mean Predicted Param 2: 1.59 Std Params:1.06  Std Log Loss:0.01
# Epoch(Adam):2000,  Total Loss:0.07  PDE Loss:0.02  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.37 Std Params:0.82  Std Log Loss:0.04
# Epoch(Adam):2100,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.46 Std Params:0.93  Std Log Loss:0.00
# Epoch(Adam):2200,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.40 Mean Predicted Param 2: 1.62 Std Params:1.14  Std Log Loss:0.02
# Epoch(Adam):2300,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.39 Mean Predicted Param 2: 1.61 Std Params:1.10  Std Log Loss:0.01
# Epoch(Adam):2400,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.21 Mean Predicted Param 2: 1.42 Std Params:0.79  Std Log Loss:0.05
# Epoch(Adam):2500,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.38 Std Params:0.83  Std Log Loss:0.03
# Epoch(Adam):2600,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.44 Std Params:0.94  Std Log Loss:0.00
# Epoch(Adam):2700,  Total Loss:0.06  PDE Loss:0.02  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.29 Mean Predicted Param 2: 1.50 Std Params:0.98  Std Log Loss:0.00
# Epoch(Adam):2800,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.25 Mean Predicted Param 2: 1.47 Std Params:0.85  Std Log Loss:0.02
# Epoch(Adam):2900,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.32 Mean Predicted Param 2: 1.54 Std Params:0.92  Std Log Loss:0.00
# Epoch(Adam):3000,  Total Loss:0.04  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.14 Mean Predicted Param 2: 1.35 Std Params:0.72  Std Log Loss:0.09
# Epoch(Adam):3100,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.26 Mean Predicted Param 2: 1.48 Std Params:0.89  Std Log Loss:0.01
# Epoch(Adam):3200,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.35 Mean Predicted Param 2: 1.57 Std Params:1.02  Std Log Loss:0.00
# Epoch(Adam):3300,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.23 Mean Predicted Param 2: 1.44 Std Params:0.93  Std Log Loss:0.00
# Epoch(Adam):3400,  Total Loss:0.04  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.27 Mean Predicted Param 2: 1.49 Std Params:0.84  Std Log Loss:0.02
# Epoch(Adam):3500,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.38 Mean Predicted Param 2: 1.60 Std Params:1.07  Std Log Loss:0.01
# Epoch(Adam):3600,  Total Loss:0.07  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.38 Mean Predicted Param 2: 1.60 Std Params:1.07  Std Log Loss:0.01
# Epoch(Adam):3700,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.43 Std Params:0.83  Std Log Loss:0.03
# Epoch(Adam):3800,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.41 Mean Predicted Param 2: 1.61 Std Params:1.25  Std Log Loss:0.05
# Epoch(Adam):3900,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.35 Mean Predicted Param 2: 1.57 Std Params:1.03  Std Log Loss:0.00
# Epoch(Adam):4000,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.34 Mean Predicted Param 2: 1.55 Std Params:1.10  Std Log Loss:0.01
# Epoch(Adam):4100,  Total Loss:0.04  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.44 Std Params:0.77  Std Log Loss:0.06
# Epoch(Adam):4200,  Total Loss:0.04  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.43 Std Params:0.81  Std Log Loss:0.04
# Epoch(Adam):4300,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.32 Std Params:0.69  Std Log Loss:0.12
# Epoch(Adam):4400,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.02  Mean Predicted Param 1: 1.32 Mean Predicted Param 2: 1.53 Std Params:0.98  Std Log Loss:0.00
# Epoch(Adam):4500,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.35 Mean Predicted Param 2: 1.56 Std Params:1.12  Std Log Loss:0.02
# Epoch(Adam):4600,  Total Loss:0.05  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.18 Mean Predicted Param 2: 1.39 Std Params:0.73  Std Log Loss:0.08
# Epoch(Adam):4700,  Total Loss:0.05  PDE Loss:0.02  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.32 Std Params:0.64  Std Log Loss:0.18
# Epoch(Adam):4800,  Total Loss:0.07  PDE Loss:0.01  BC Loss:0.01  IC Loss: 0.03  Mean Predicted Param 1: 1.49 Mean Predicted Param 2: 1.72 Std Params:1.17  Std Log Loss:0.03
# Epoch(Adam):4900,  Total Loss:0.06  PDE Loss:0.01  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.27 Mean Predicted Param 2: 1.49 Std Params:0.91  Std Log Loss:0.01
# cuda:0
# Trying: w_ic=2, w_int=0.5, w_bc=0.5, w_data=2, w_param_std=1
# Epoch(Adam):0,  Total Loss:27.05  PDE Loss:26.36  BC Loss:0.03  IC Loss: 0.47  Mean Predicted Param 1: -0.06 Mean Predicted Param 2: 0.20 Std Params:0.05  Std Log Loss:10.41
# Epoch(Adam):100,  Total Loss:0.81  PDE Loss:0.36  BC Loss:0.19  IC Loss: 0.15  Mean Predicted Param 1: 4.37 Mean Predicted Param 2: 6.61 Std Params:0.82  Std Log Loss:0.03
# Epoch(Adam):200,  Total Loss:0.55  PDE Loss:0.20  BC Loss:0.18  IC Loss: 0.08  Mean Predicted Param 1: 3.07 Mean Predicted Param 2: 6.18 Std Params:0.91  Std Log Loss:0.01
# Epoch(Adam):300,  Total Loss:0.47  PDE Loss:0.24  BC Loss:0.11  IC Loss: 0.04  Mean Predicted Param 1: 2.02 Mean Predicted Param 2: 6.02 Std Params:0.87  Std Log Loss:0.01
# Epoch(Adam):400,  Total Loss:0.38  PDE Loss:0.18  BC Loss:0.13  IC Loss: 0.02  Mean Predicted Param 1: 1.41 Mean Predicted Param 2: 5.89 Std Params:0.73  Std Log Loss:0.05
# Epoch(Adam):500,  Total Loss:0.33  PDE Loss:0.18  BC Loss:0.06  IC Loss: 0.02  Mean Predicted Param 1: 1.54 Mean Predicted Param 2: 5.85 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):600,  Total Loss:0.27  PDE Loss:0.12  BC Loss:0.09  IC Loss: 0.02  Mean Predicted Param 1: 1.39 Mean Predicted Param 2: 5.46 Std Params:1.02  Std Log Loss:0.00
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=2, w_int=0.5, w_bc=0.5, w_data=4, w_param_std=1
# Epoch(Adam):0,  Total Loss:29.80  PDE Loss:29.09  BC Loss:0.01  IC Loss: 0.51  Mean Predicted Param 1: 0.20 Mean Predicted Param 2: 0.15 Std Params:0.06  Std Log Loss:9.56
# Epoch(Adam):100,  Total Loss:0.92  PDE Loss:0.39  BC Loss:0.29  IC Loss: 0.14  Mean Predicted Param 1: 4.39 Mean Predicted Param 2: 5.91 Std Params:0.79  Std Log Loss:0.07
# Epoch(Adam):200,  Total Loss:1.03  PDE Loss:0.66  BC Loss:0.18  IC Loss: 0.09  Mean Predicted Param 1: 3.32 Mean Predicted Param 2: 5.69 Std Params:0.83  Std Log Loss:0.02
# Epoch(Adam):300,  Total Loss:0.43  PDE Loss:0.21  BC Loss:0.11  IC Loss: 0.04  Mean Predicted Param 1: 1.80 Mean Predicted Param 2: 4.99 Std Params:0.71  Std Log Loss:0.06
# Epoch(Adam):400,  Total Loss:0.34  PDE Loss:0.18  BC Loss:0.10  IC Loss: 0.02  Mean Predicted Param 1: 1.53 Mean Predicted Param 2: 4.27 Std Params:0.93  Std Log Loss:0.01
# Epoch(Adam):500,  Total Loss:0.16  PDE Loss:0.07  BC Loss:0.05  IC Loss: 0.02  Mean Predicted Param 1: 1.46 Mean Predicted Param 2: 3.18 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):600,  Total Loss:0.29  PDE Loss:0.19  BC Loss:0.05  IC Loss: 0.03  Mean Predicted Param 1: 1.74 Mean Predicted Param 2: 2.74 Std Params:1.38  Std Log Loss:0.11
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=2, w_int=0.5, w_bc=0.5, w_data=6, w_param_std=1
# Epoch(Adam):0,  Total Loss:27.46  PDE Loss:26.70  BC Loss:0.00  IC Loss: 0.57  Mean Predicted Param 1: -0.01 Mean Predicted Param 2: -0.06 Std Params:0.05  Std Log Loss:9.31
# Epoch(Adam):100,  Total Loss:0.98  PDE Loss:0.45  BC Loss:0.31  IC Loss: 0.13  Mean Predicted Param 1: 3.28 Mean Predicted Param 2: 4.27 Std Params:0.99  Std Log Loss:0.01
# Epoch(Adam):200,  Total Loss:0.51  PDE Loss:0.26  BC Loss:0.15  IC Loss: 0.05  Mean Predicted Param 1: 1.66 Mean Predicted Param 2: 4.62 Std Params:0.66  Std Log Loss:0.09
# Epoch(Adam):300,  Total Loss:0.44  PDE Loss:0.31  BC Loss:0.06  IC Loss: 0.03  Mean Predicted Param 1: 1.38 Mean Predicted Param 2: 2.72 Std Params:0.92  Std Log Loss:0.01
# Epoch(Adam):400,  Total Loss:0.25  PDE Loss:0.18  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.26 Mean Predicted Param 2: 1.96 Std Params:0.88  Std Log Loss:0.01
# Epoch(Adam):500,  Total Loss:0.40  PDE Loss:0.31  BC Loss:0.05  IC Loss: 0.01  Mean Predicted Param 1: 1.21 Mean Predicted Param 2: 1.86 Std Params:0.87  Std Log Loss:0.01
# Epoch(Adam):600,  Total Loss:0.27  PDE Loss:0.21  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.15 Mean Predicted Param 2: 1.79 Std Params:0.86  Std Log Loss:0.01
# Epoch(Adam):700,  Total Loss:0.31  PDE Loss:0.24  BC Loss:0.04  IC Loss: 0.01  Mean Predicted Param 1: 1.18 Mean Predicted Param 2: 1.87 Std Params:0.78  Std Log Loss:0.04
# Epoch(Adam):800,  Total Loss:0.33  PDE Loss:0.26  BC Loss:0.04  IC Loss: 0.01  Mean Predicted Param 1: 1.31 Mean Predicted Param 2: 1.85 Std Params:0.99  Std Log Loss:0.00
# Epoch(Adam):900,  Total Loss:0.18  PDE Loss:0.13  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.28 Mean Predicted Param 2: 1.75 Std Params:1.01  Std Log Loss:0.00
# Epoch(Adam):1000,  Total Loss:0.20  PDE Loss:0.17  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.27 Mean Predicted Param 2: 1.71 Std Params:1.05  Std Log Loss:0.00
# Epoch(Adam):1100,  Total Loss:0.11  PDE Loss:0.05  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.02 Mean Predicted Param 2: 1.89 Std Params:0.68  Std Log Loss:0.09
# Epoch(Adam):1200,  Total Loss:0.16  PDE Loss:0.11  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.31 Mean Predicted Param 2: 1.65 Std Params:1.11  Std Log Loss:0.01
# Epoch(Adam):1300,  Total Loss:0.11  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.33 Mean Predicted Param 2: 1.50 Std Params:1.01  Std Log Loss:0.00
# Epoch(Adam):1400,  Total Loss:0.23  PDE Loss:0.18  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.32 Mean Predicted Param 2: 1.51 Std Params:1.04  Std Log Loss:0.00
# Epoch(Adam):1500,  Total Loss:0.14  PDE Loss:0.09  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.27 Mean Predicted Param 2: 1.56 Std Params:1.02  Std Log Loss:0.00
# Epoch(Adam):1600,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.25 Mean Predicted Param 2: 1.52 Std Params:0.99  Std Log Loss:0.00
# Epoch(Adam):1700,  Total Loss:0.13  PDE Loss:0.08  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.30 Mean Predicted Param 2: 1.44 Std Params:0.95  Std Log Loss:0.00
# Epoch(Adam):1800,  Total Loss:0.24  PDE Loss:0.20  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.09 Mean Predicted Param 2: 1.69 Std Params:0.78  Std Log Loss:0.04
# Epoch(Adam):1900,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.13 Mean Predicted Param 2: 1.68 Std Params:0.84  Std Log Loss:0.02
# Epoch(Adam):2000,  Total Loss:0.13  PDE Loss:0.08  BC Loss:0.04  IC Loss: 0.01  Mean Predicted Param 1: 1.28 Mean Predicted Param 2: 1.51 Std Params:1.03  Std Log Loss:0.00
# Epoch(Adam):2100,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.14 Mean Predicted Param 2: 1.60 Std Params:0.87  Std Log Loss:0.02
# Epoch(Adam):2200,  Total Loss:0.12  PDE Loss:0.08  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.10 Mean Predicted Param 2: 1.66 Std Params:0.77  Std Log Loss:0.04
# Epoch(Adam):2300,  Total Loss:0.12  PDE Loss:0.08  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.66 Std Params:0.81  Std Log Loss:0.03
# Epoch(Adam):2400,  Total Loss:0.14  PDE Loss:0.08  BC Loss:0.03  IC Loss: 0.02  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.50 Std Params:0.92  Std Log Loss:0.00
# Epoch(Adam):2500,  Total Loss:0.12  PDE Loss:0.07  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.16 Mean Predicted Param 2: 1.63 Std Params:0.89  Std Log Loss:0.01
# Epoch(Adam):2600,  Total Loss:0.14  PDE Loss:0.09  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.52 Std Params:0.96  Std Log Loss:0.00
# Epoch(Adam):2700,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.54 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):2800,  Total Loss:0.14  PDE Loss:0.09  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.28 Mean Predicted Param 2: 1.50 Std Params:1.04  Std Log Loss:0.00
# Epoch(Adam):2900,  Total Loss:0.14  PDE Loss:0.09  BC Loss:0.03  IC Loss: 0.02  Mean Predicted Param 1: 1.18 Mean Predicted Param 2: 1.59 Std Params:0.87  Std Log Loss:0.01
# Epoch(Adam):3000,  Total Loss:0.13  PDE Loss:0.08  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.10 Mean Predicted Param 2: 1.64 Std Params:0.76  Std Log Loss:0.05
# Epoch(Adam):3100,  Total Loss:0.11  PDE Loss:0.06  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.55 Std Params:0.95  Std Log Loss:0.00
# Epoch(Adam):3200,  Total Loss:0.10  PDE Loss:0.07  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.49 Std Params:0.95  Std Log Loss:0.00
# Epoch(Adam):3300,  Total Loss:0.11  PDE Loss:0.06  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.56 Std Params:0.81  Std Log Loss:0.02
# Epoch(Adam):3400,  Total Loss:0.11  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.08 Mean Predicted Param 2: 1.70 Std Params:0.82  Std Log Loss:0.03
# Epoch(Adam):3500,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.16 Mean Predicted Param 2: 1.65 Std Params:0.95  Std Log Loss:0.00
# Epoch(Adam):3600,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.19 Mean Predicted Param 2: 1.64 Std Params:0.99  Std Log Loss:0.00
# Epoch(Adam):3700,  Total Loss:0.13  PDE Loss:0.06  BC Loss:0.04  IC Loss: 0.01  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.43 Std Params:0.80  Std Log Loss:0.03
# Epoch(Adam):3800,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.35 Mean Predicted Param 2: 1.51 Std Params:1.17  Std Log Loss:0.01
# Epoch(Adam):3900,  Total Loss:0.12  PDE Loss:0.07  BC Loss:0.03  IC Loss: 0.02  Mean Predicted Param 1: 1.16 Mean Predicted Param 2: 1.68 Std Params:0.90  Std Log Loss:0.01
# ...
# Epoch(Adam):500,  Total Loss:0.24  PDE Loss:0.20  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.05 Mean Predicted Param 2: 1.75 Std Params:0.68  Std Log Loss:0.08
# Epoch(Adam):600,  Total Loss:0.40  PDE Loss:0.34  BC Loss:0.03  IC Loss: 0.02  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.82 Std Params:0.68  Std Log Loss:0.08
# Epoch(Adam):700,  Total Loss:0.30  PDE Loss:0.25  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.06 Mean Predicted Param 2: 1.75 Std Params:0.62  Std Log Loss:0.12
# Epoch(Adam):800,  Total Loss:0.12  PDE Loss:0.08  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.22 Mean Predicted Param 2: 1.57 Std Params:0.83  Std Log Loss:0.02
# Epoch(Adam):900,  Total Loss:0.16  PDE Loss:0.12  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.65 Std Params:0.84  Std Log Loss:0.02
# Epoch(Adam):1000,  Total Loss:0.30  PDE Loss:0.25  BC Loss:0.03  IC Loss: 0.02  Mean Predicted Param 1: 1.13 Mean Predicted Param 2: 1.91 Std Params:0.96  Std Log Loss:0.00
# Epoch(Adam):1100,  Total Loss:0.14  PDE Loss:0.11  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.12 Mean Predicted Param 2: 1.75 Std Params:0.85  Std Log Loss:0.01
# Epoch(Adam):1200,  Total Loss:0.15  PDE Loss:0.12  BC Loss:0.01  IC Loss: 0.00  Mean Predicted Param 1: 1.00 Mean Predicted Param 2: 1.89 Std Params:0.68  Std Log Loss:0.09
# Epoch(Adam):1300,  Total Loss:0.13  PDE Loss:0.09  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.27 Mean Predicted Param 2: 1.64 Std Params:1.10  Std Log Loss:0.01
# Epoch(Adam):1400,  Total Loss:0.10  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.67 Std Params:1.12  Std Log Loss:0.01
# Epoch(Adam):1500,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.20 Mean Predicted Param 2: 1.62 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):1600,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.18 Mean Predicted Param 2: 1.62 Std Params:0.96  Std Log Loss:0.00
# Epoch(Adam):1700,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.13 Mean Predicted Param 2: 1.63 Std Params:0.92  Std Log Loss:0.01
# Epoch(Adam):1800,  Total Loss:0.08  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.13 Mean Predicted Param 2: 1.62 Std Params:0.87  Std Log Loss:0.02
# Epoch(Adam):1900,  Total Loss:0.10  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.07 Mean Predicted Param 2: 1.64 Std Params:0.66  Std Log Loss:0.10
# Epoch(Adam):2000,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.08 Mean Predicted Param 2: 1.74 Std Params:0.82  Std Log Loss:0.03
# Epoch(Adam):2100,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.30 Mean Predicted Param 2: 1.45 Std Params:1.05  Std Log Loss:0.00
# Epoch(Adam):2200,  Total Loss:0.10  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.54 Std Params:1.06  Std Log Loss:0.00
# Epoch(Adam):2300,  Total Loss:0.10  PDE Loss:0.07  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.01 Mean Predicted Param 2: 1.81 Std Params:0.73  Std Log Loss:0.06
# Epoch(Adam):2400,  Total Loss:0.10  PDE Loss:0.07  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.16 Mean Predicted Param 2: 1.60 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):2500,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.05 Mean Predicted Param 2: 1.74 Std Params:0.81  Std Log Loss:0.03
# Epoch(Adam):2600,  Total Loss:0.11  PDE Loss:0.07  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.21 Mean Predicted Param 2: 1.58 Std Params:1.06  Std Log Loss:0.00
# Epoch(Adam):2700,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.21 Mean Predicted Param 2: 1.53 Std Params:0.97  Std Log Loss:0.00
# Epoch(Adam):2800,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.10 Mean Predicted Param 2: 1.71 Std Params:0.91  Std Log Loss:0.01
# Epoch(Adam):2900,  Total Loss:0.12  PDE Loss:0.09  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.26 Mean Predicted Param 2: 1.55 Std Params:1.08  Std Log Loss:0.00
# Epoch(Adam):3000,  Total Loss:0.10  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.05 Mean Predicted Param 2: 1.71 Std Params:0.72  Std Log Loss:0.06
# Epoch(Adam):3100,  Total Loss:0.12  PDE Loss:0.08  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.27 Mean Predicted Param 2: 1.48 Std Params:1.06  Std Log Loss:0.00
# Epoch(Adam):3200,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.09 Mean Predicted Param 2: 1.63 Std Params:0.77  Std Log Loss:0.04
# Epoch(Adam):3300,  Total Loss:0.08  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.13 Mean Predicted Param 2: 1.62 Std Params:0.89  Std Log Loss:0.01
# Epoch(Adam):3400,  Total Loss:0.10  PDE Loss:0.07  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.06 Mean Predicted Param 2: 1.77 Std Params:0.89  Std Log Loss:0.01
# Epoch(Adam):3500,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.10 Mean Predicted Param 2: 1.70 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):3600,  Total Loss:0.09  PDE Loss:0.05  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.03 Mean Predicted Param 2: 1.72 Std Params:0.77  Std Log Loss:0.06
# Epoch(Adam):3700,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.13 Mean Predicted Param 2: 1.61 Std Params:0.89  Std Log Loss:0.01
# Epoch(Adam):3800,  Total Loss:0.13  PDE Loss:0.10  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.25 Mean Predicted Param 2: 1.52 Std Params:0.99  Std Log Loss:0.00
# Epoch(Adam):3900,  Total Loss:0.07  PDE Loss:0.03  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.19 Mean Predicted Param 2: 1.61 Std Params:1.02  Std Log Loss:0.00
# Epoch(Adam):4000,  Total Loss:0.08  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.18 Mean Predicted Param 2: 1.56 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):4100,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.30 Mean Predicted Param 2: 1.56 Std Params:1.15  Std Log Loss:0.01
# Epoch(Adam):4200,  Total Loss:0.06  PDE Loss:0.05  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 0.99 Mean Predicted Param 2: 1.79 Std Params:0.70  Std Log Loss:0.09
# Epoch(Adam):4300,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 1.55 Std Params:0.87  Std Log Loss:0.01
# Epoch(Adam):4400,  Total Loss:0.12  PDE Loss:0.09  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 0.96 Mean Predicted Param 2: 1.77 Std Params:0.62  Std Log Loss:0.16
# Epoch(Adam):4500,  Total Loss:0.09  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.19 Mean Predicted Param 2: 1.54 Std Params:0.85  Std Log Loss:0.01
# Epoch(Adam):4600,  Total Loss:0.10  PDE Loss:0.07  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.00 Mean Predicted Param 2: 1.74 Std Params:0.68  Std Log Loss:0.10
# Epoch(Adam):4700,  Total Loss:0.07  PDE Loss:0.04  BC Loss:0.01  IC Loss: 0.01  Mean Predicted Param 1: 1.11 Mean Predicted Param 2: 1.65 Std Params:0.86  Std Log Loss:0.02
# Epoch(Adam):4800,  Total Loss:0.10  PDE Loss:0.05  BC Loss:0.02  IC Loss: 0.02  Mean Predicted Param 1: 1.24 Mean Predicted Param 2: 1.47 Std Params:0.98  Std Log Loss:0.00
# Epoch(Adam):4900,  Total Loss:0.10  PDE Loss:0.06  BC Loss:0.02  IC Loss: 0.01  Mean Predicted Param 1: 1.06 Mean Predicted Param 2: 1.69 Std Params:0.75  Std Log Loss:0.05
# cuda:0
# Trying: w_ic=3, w_int=1, w_bc=0.5, w_data=2, w_param_std=1
# Epoch(Adam):0,  Total Loss:40.95  PDE Loss:40.23  BC Loss:0.02  IC Loss: 0.51  Mean Predicted Param 1: -0.08 Mean Predicted Param 2: -0.23 Std Params:0.05  Std Log Loss:9.05
# Epoch(Adam):100,  Total Loss:0.62  PDE Loss:0.16  BC Loss:0.23  IC Loss: 0.14  Mean Predicted Param 1: 3.71 Mean Predicted Param 2: 3.97 Std Params:0.81  Std Log Loss:0.02
# Epoch(Adam):200,  Total Loss:0.52  PDE Loss:0.19  BC Loss:0.16  IC Loss: 0.08  Mean Predicted Param 1: 2.41 Mean Predicted Param 2: 4.58 Std Params:0.78  Std Log Loss:0.03
# Epoch(Adam):300,  Total Loss:0.38  PDE Loss:0.18  BC Loss:0.12  IC Loss: 0.03  Mean Predicted Param 1: 1.56 Mean Predicted Param 2: 4.65 Std Params:0.63  Std Log Loss:0.11
# Epoch(Adam):400,  Total Loss:0.37  PDE Loss:0.17  BC Loss:0.11  IC Loss: 0.03  Mean Predicted Param 1: 1.51 Mean Predicted Param 2: 4.47 Std Params:0.91  Std Log Loss:0.01
# Epoch(Adam):500,  Total Loss:0.31  PDE Loss:0.16  BC Loss:0.09  IC Loss: 0.02  Mean Predicted Param 1: 1.46 Mean Predicted Param 2: 4.23 Std Params:1.02  Std Log Loss:0.01
# Epoch(Adam):600,  Total Loss:0.26  PDE Loss:0.10  BC Loss:0.08  IC Loss: 0.02  Mean Predicted Param 1: 1.30 Mean Predicted Param 2: 4.49 Std Params:0.79  Std Log Loss:0.03
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=3, w_int=1, w_bc=0.5, w_data=4, w_param_std=1
# Epoch(Adam):0,  Total Loss:35.38  PDE Loss:34.69  BC Loss:0.01  IC Loss: 0.47  Mean Predicted Param 1: 0.01 Mean Predicted Param 2: -0.37 Std Params:0.04  Std Log Loss:9.67
# Epoch(Adam):100,  Total Loss:0.63  PDE Loss:0.13  BC Loss:0.30  IC Loss: 0.10  Mean Predicted Param 1: 3.27 Mean Predicted Param 2: 4.59 Std Params:0.81  Std Log Loss:0.02
# Epoch(Adam):200,  Total Loss:0.60  PDE Loss:0.32  BC Loss:0.15  IC Loss: 0.05  Mean Predicted Param 1: 1.76 Mean Predicted Param 2: 5.75 Std Params:0.84  Std Log Loss:0.02
# Epoch(Adam):300,  Total Loss:0.38  PDE Loss:0.18  BC Loss:0.11  IC Loss: 0.02  Mean Predicted Param 1: 1.68 Mean Predicted Param 2: 5.68 Std Params:0.75  Std Log Loss:0.05
# Epoch(Adam):400,  Total Loss:0.36  PDE Loss:0.21  BC Loss:0.07  IC Loss: 0.02  Mean Predicted Param 1: 1.30 Mean Predicted Param 2: 5.29 Std Params:0.74  Std Log Loss:0.05
# Epoch(Adam):500,  Total Loss:0.26  PDE Loss:0.11  BC Loss:0.09  IC Loss: 0.02  Mean Predicted Param 1: 1.17 Mean Predicted Param 2: 5.04 Std Params:0.55  Std Log Loss:0.21
# Epoch(Adam):600,  Total Loss:0.22  PDE Loss:0.08  BC Loss:0.09  IC Loss: 0.02  Mean Predicted Param 1: 1.01 Mean Predicted Param 2: 4.78 Std Params:0.62  Std Log Loss:0.12
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=3, w_int=1, w_bc=0.5, w_data=6, w_param_std=1
# Epoch(Adam):0,  Total Loss:30.39  PDE Loss:29.66  BC Loss:0.06  IC Loss: 0.46  Mean Predicted Param 1: 0.13 Mean Predicted Param 2: -0.06 Std Params:0.05  Std Log Loss:8.66
# Epoch(Adam):100,  Total Loss:0.76  PDE Loss:0.24  BC Loss:0.28  IC Loss: 0.13  Mean Predicted Param 1: 3.63 Mean Predicted Param 2: 4.62 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):200,  Total Loss:0.45  PDE Loss:0.14  BC Loss:0.17  IC Loss: 0.07  Mean Predicted Param 1: 2.17 Mean Predicted Param 2: 5.24 Std Params:0.77  Std Log Loss:0.03
# Epoch(Adam):300,  Total Loss:0.36  PDE Loss:0.18  BC Loss:0.10  IC Loss: 0.03  Mean Predicted Param 1: 1.51 Mean Predicted Param 2: 4.96 Std Params:0.68  Std Log Loss:0.07
# Epoch(Adam):400,  Total Loss:0.51  PDE Loss:0.29  BC Loss:0.15  IC Loss: 0.03  Mean Predicted Param 1: 1.27 Mean Predicted Param 2: 4.56 Std Params:0.52  Std Log Loss:0.21
# Epoch(Adam):500,  Total Loss:0.38  PDE Loss:0.26  BC Loss:0.08  IC Loss: 0.02  Mean Predicted Param 1: 1.15 Mean Predicted Param 2: 3.71 Std Params:0.66  Std Log Loss:0.09
# Epoch(Adam):600,  Total Loss:0.25  PDE Loss:0.13  BC Loss:0.07  IC Loss: 0.03  Mean Predicted Param 1: 1.09 Mean Predicted Param 2: 2.88 Std Params:0.69  Std Log Loss:0.07
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=3, w_int=1, w_bc=1, w_data=2, w_param_std=1
# Epoch(Adam):0,  Total Loss:29.35  PDE Loss:28.67  BC Loss:0.01  IC Loss: 0.48  Mean Predicted Param 1: 0.14 Mean Predicted Param 2: -0.04 Std Params:0.05  Std Log Loss:10.08
# Epoch(Adam):100,  Total Loss:0.50  PDE Loss:0.10  BC Loss:0.17  IC Loss: 0.12  Mean Predicted Param 1: 3.66 Mean Predicted Param 2: 5.29 Std Params:0.82  Std Log Loss:0.02
# Epoch(Adam):200,  Total Loss:0.36  PDE Loss:0.12  BC Loss:0.10  IC Loss: 0.06  Mean Predicted Param 1: 1.89 Mean Predicted Param 2: 6.56 Std Params:0.71  Std Log Loss:0.07
# Epoch(Adam):300,  Total Loss:0.42  PDE Loss:0.23  BC Loss:0.06  IC Loss: 0.05  Mean Predicted Param 1: 1.75 Mean Predicted Param 2: 6.13 Std Params:0.85  Std Log Loss:0.03
# Epoch(Adam):400,  Total Loss:0.22  PDE Loss:0.07  BC Loss:0.05  IC Loss: 0.02  Mean Predicted Param 1: 1.36 Mean Predicted Param 2: 6.08 Std Params:0.70  Std Log Loss:0.06
# Epoch(Adam):500,  Total Loss:0.28  PDE Loss:0.14  BC Loss:0.07  IC Loss: 0.02  Mean Predicted Param 1: 1.28 Mean Predicted Param 2: 6.00 Std Params:0.83  Std Log Loss:0.02
# Epoch(Adam):600,  Total Loss:0.20  PDE Loss:0.08  BC Loss:0.04  IC Loss: 0.02  Mean Predicted Param 1: 1.60 Mean Predicted Param 2: 5.16 Std Params:1.03  Std Log Loss:0.02
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=3, w_int=1, w_bc=1, w_data=4, w_param_std=1
# Epoch(Adam):0,  Total Loss:35.38  PDE Loss:34.70  BC Loss:0.01  IC Loss: 0.47  Mean Predicted Param 1: -0.16 Mean Predicted Param 2: -0.11 Std Params:0.06  Std Log Loss:9.33
# Epoch(Adam):100,  Total Loss:0.65  PDE Loss:0.23  BC Loss:0.15  IC Loss: 0.15  Mean Predicted Param 1: 4.70 Mean Predicted Param 2: 5.33 Std Params:0.81  Std Log Loss:0.06
# Epoch(Adam):200,  Total Loss:0.40  PDE Loss:0.11  BC Loss:0.11  IC Loss: 0.09  Mean Predicted Param 1: 3.10 Mean Predicted Param 2: 5.12 Std Params:0.90  Std Log Loss:0.01
# Epoch(Adam):300,  Total Loss:0.55  PDE Loss:0.29  BC Loss:0.13  IC Loss: 0.05  Mean Predicted Param 1: 1.84 Mean Predicted Param 2: 4.95 Std Params:0.71  Std Log Loss:0.07
# Epoch(Adam):400,  Total Loss:0.34  PDE Loss:0.17  BC Loss:0.09  IC Loss: 0.02  Mean Predicted Param 1: 1.53 Mean Predicted Param 2: 4.83 Std Params:0.78  Std Log Loss:0.03
# Epoch(Adam):500,  Total Loss:0.26  PDE Loss:0.13  BC Loss:0.06  IC Loss: 0.02  Mean Predicted Param 1: 1.27 Mean Predicted Param 2: 4.26 Std Params:0.77  Std Log Loss:0.03
# Epoch(Adam):600,  Total Loss:0.19  PDE Loss:0.09  BC Loss:0.04  IC Loss: 0.02  Mean Predicted Param 1: 1.30 Mean Predicted Param 2: 3.56 Std Params:0.89  Std Log Loss:0.01
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
# cuda:0
# Trying: w_ic=3, w_int=1, w_bc=1, w_data=6, w_param_std=1
# Epoch(Adam):0,  Total Loss:27.86  PDE Loss:27.07  BC Loss:0.04  IC Loss: 0.54  Mean Predicted Param 1: 0.06 Mean Predicted Param 2: 0.05 Std Params:0.04  Std Log Loss:10.97
# Epoch(Adam):100,  Total Loss:0.61  PDE Loss:0.21  BC Loss:0.22  IC Loss: 0.10  Mean Predicted Param 1: 2.92 Mean Predicted Param 2: 4.67 Std Params:0.75  Std Log Loss:0.04
# Epoch(Adam):200,  Total Loss:0.49  PDE Loss:0.24  BC Loss:0.12  IC Loss: 0.06  Mean Predicted Param 1: 1.87 Mean Predicted Param 2: 4.55 Std Params:0.72  Std Log Loss:0.06
# Epoch(Adam):300,  Total Loss:0.31  PDE Loss:0.14  BC Loss:0.09  IC Loss: 0.03  Mean Predicted Param 1: 1.15 Mean Predicted Param 2: 3.93 Std Params:0.58  Std Log Loss:0.15
# Epoch(Adam):400,  Total Loss:0.39  PDE Loss:0.24  BC Loss:0.10  IC Loss: 0.02  Mean Predicted Param 1: 1.27 Mean Predicted Param 2: 3.17 Std Params:0.75  Std Log Loss:0.04
# Epoch(Adam):500,  Total Loss:0.31  PDE Loss:0.19  BC Loss:0.08  IC Loss: 0.02  Mean Predicted Param 1: 1.01 Mean Predicted Param 2: 3.25 Std Params:0.54  Std Log Loss:0.19
# Epoch(Adam):600,  Total Loss:0.26  PDE Loss:0.20  BC Loss:0.03  IC Loss: 0.01  Mean Predicted Param 1: 1.03 Mean Predicted Param 2: 2.83 Std Params:0.67  Std Log Loss:0.08
# Early stopping: Mean Predicted Param 1 or 2 out of range [1, 2] for 7 logs.
#
# Best weights found:
# w_ic=1, w_int=1, w_bc=1, w_data=6, w_param_std=1
