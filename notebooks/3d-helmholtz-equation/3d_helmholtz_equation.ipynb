# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import spherical_jn
import torch.nn.functional as F


# Exact solution for ℓ=1,m=0 dipole mode
def exact_solution(x, y, z, k=4.493409, eps=1e-6):
    r = torch.sqrt(x**2 + y**2 + z**2 + eps)
    kr = k * r
    j1 = torch.sin(kr) / (kr**2) - torch.cos(kr) / kr
    return j1 * (z / r)


class Experiment(nn.Module):
    def __init__(self, num_samples=1000, bc_factor=2, num_data=200):
        super().__init__()
        # Device
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

        # self.lambda_param = nn.Parameter(torch.tensor(1.0, requires_grad=True, device=self.device))
        self.lambda_param = torch.tensor(1.0, requires_grad=True, device=self.device)

        # Branch Network
        self.b1 = nn.Linear(3, 20).to(self.device)
        self.b2 = nn.Linear(20, 20).to(self.device)
        self.b3 = nn.Linear(20, 1).to(self.device)

        # Trunk Network
        self.t1 = nn.Linear(3, 20).to(self.device)
        self.t2 = nn.Linear(20, 20).to(self.device)
        self.t3 = nn.Linear(20, 1).to(self.device)

        # Loss weights (set later in curriculum)
        self.w_int = 1.0
        self.w_bc = 1.0
        self.w_data = 1.0
        self.w_norm = 0.1

        # Dataset sizes
        self.num_samples = num_samples
        self.bc_samples = int(num_samples * bc_factor)
        self.num_data = num_data

        # Prepare datasets
        self.create_dataset()

        # Initialize loss history
        self.loss_history = []
        self.li_history = []
        self.lb_history = []
        self.ld_history = []

    def create_dataset(self):
        N = self.num_samples
        R = torch.rand(N,1,device=self.device)**(1/3)
        X = torch.randn(N,3,device=self.device)
        X = X / X.norm(dim=1,keepdim=True)
        self.interior = (X * R).requires_grad_(True)

        M = self.bc_samples
        B = torch.randn(M,3,device=self.device)
        B = B / B.norm(dim=1,keepdim=True)
        self.boundary = B.requires_grad_(True)

        D = self.num_data
        Rd = torch.rand(D,1,device=self.device)**(1/3)
        Xd = torch.randn(D,3,device=self.device)
        Xd = Xd / Xd.norm(dim=1,keepdim=True)
        self.data_points = (Xd * Rd)

        x_d, y_d, z_d = self.data_points[:,0], self.data_points[:,1], self.data_points[:,2]
        self.data_values = exact_solution(x_d, y_d, z_d).detach()

    def forward(self, x, resample_param=True):
        h = torch.tanh(self.b1(x))
        h = torch.tanh(self.b2(h))

        x_trunk = torch.normal(mean=0, std=1, size=(x.shape[0], 3), device=self.device)
        t = torch.tanh(self.t1(x_trunk))
        prod = t*h
        u = self.b3(prod).squeeze(-1)
        param = torch.tanh(self.t2(t))
        self.lambda_param = F.relu(self.t3(param))

        return u

    def laplacian(self, u, x):
        grad_u = torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u), create_graph=True)[0]
        lap = torch.zeros_like(u)
        for i in range(3):
            grad2 = torch.autograd.grad(grad_u[:,i], x, grad_outputs=torch.ones_like(grad_u[:,i]), create_graph=True)[0]
            lap += grad2[:,i]
        return lap

    def loss_interior(self, resample_param=True):
        x = self.interior
        u = self.forward(x, resample_param=resample_param)
        lap_u = self.laplacian(u, x).squeeze(-1)
        lap_u = lap_u.squeeze(-1)

        res = -lap_u - (self.lambda_param ** 2) * u
        loss_pde = torch.mean(res**2)
        # loss_norm = (torch.mean(u**2) - 1.0)**2
        return loss_pde

    def check_exact_residual(self):
        x = self.interior           # (N,3) with requires_grad=True
        # exact u, keep requires_grad so autograd works
        exact_u = exact_solution(x[:,0], x[:,1], x[:,2])

        lap_exact = self.laplacian(exact_u, x)   # Laplacian of the *exact* field
        lap_exact = lap_exact.squeeze(-1)        # make it (N,) not (N,1)

        k = 4.493409
        residual = -lap_exact - (k**2) * exact_u

        # print("max |residual| =", residual.abs().max().item())
        print(" norm |residual| =", (residual**2).mean().item())

    def loss_boundary(self):
        u_b = self.forward(self.boundary)
        return torch.mean(u_b**2)

    def loss_data(self):
        u_d = self.forward(self.data_points)
        return torch.mean((u_d - self.data_values)**2)

    def compute_losses(self):
        return self.loss_interior(), self.loss_boundary(), self.loss_data()

# %%
# Training and plotting helpers
def pretrain(model, epochs=10, lr=1e-3):
    model.w_int = 1.0
    model.w_bc = 0.0
    model.w_norm = 0.0
    model.w_data = 1.0

    optimizer = optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        optimizer.zero_grad()
        loss_d = model.loss_data()
        loss_d.backward()
        optimizer.step()
        if epoch % 50 == 0:
            print(f"Pretrain epoch {epoch}: data_loss={loss_d.item():.2e}")

# def train_full(model, epochs=1000, lr=1e-4):
#     model.w_int  = 10.0
#     model.w_bc   = 1.0
#     model.w_norm = 100.0
#     model.w_data = 100.0

#     optimizer = optim.Adam(model.parameters(), lr=lr)
#     for epoch in range(epochs):
#         optimizer.zero_grad()
#         model.create_dataset()
#         li, lb, ld = model.compute_losses()
#         loss = model.w_int*li + model.w_bc*lb + model.w_data*ld
#         loss.backward()
#         optimizer.step()
#         if epoch % 100 == 0:
#             print(f"Epoch {epoch}: PDE={li.item():.2e}, BC={lb.item():.2e}, DATA={ld.item():.2e}, λ={model.lambda_param.mean().item():.4f}")


def train_full(model, epochs=1000, lr=1e-4):
    model.w_int  = 10.0
    model.w_bc   = 1.0
    model.w_norm = 100.0
    model.w_data = 100.0

    optimizer = optim.Adam(model.parameters(), lr=lr)

    # No need to create local histories; use model attributes!
    for epoch in range(epochs):
        optimizer.zero_grad()
        model.create_dataset()
        li, lb, ld = model.compute_losses()
        loss = model.w_int*li + model.w_bc*lb + model.w_data*ld
        loss.backward()
        optimizer.step()

        if epoch % 100 == 0:
            # Append losses to model’s history arrays
            model.loss_history.append(loss.item())
            model.li_history.append(li.item())
            model.lb_history.append(lb.item())
            model.ld_history.append(ld.item())
            print(
                f"Epoch {epoch}: Total Loss={loss.item():.2e}, PDE={li.item():.2e}, "
                f"BC={lb.item():.2e}, DATA={ld.item():.2e}, λ={model.lambda_param.mean().item():.4f}"
            )



def plot_axis(model):
    z = torch.linspace(-1,1,200,device=model.device)
    pts = torch.stack([torch.zeros_like(z), torch.zeros_like(z), z], dim=1)
    with torch.no_grad():
        u_pred = model(pts).cpu().numpy()
    z_np = z.cpu().numpy()
    u_ex = exact_solution(pts[:,0],pts[:,1],pts[:,2]).cpu().numpy()
    plt.plot(z_np, u_pred, label='Predicted')
    plt.plot(z_np, u_ex, '--', label='Exact')
    plt.legend()
    plt.xlabel('z')
    plt.ylabel('u')
    plt.title('Axis (x=y=0)')
    plt.tight_layout()
    plt.show()

def plot_slices(model, device, z0_list=(0.0, 0.3, 0.6)):
    """
    Compare u_pred vs. exact on:
      • axial line (x=y=0)
      • several horizontal slices z = z0
      • meridional slice (x=0 plane)

    z0_list : tuple of z-heights for the equatorial slices
    """
    model.eval()
    with torch.no_grad():
        # ---- 2) equatorial slices z = z0 --------------------
        for z0 in z0_list:
            r_max = np.sqrt(max(1e-8, 1 - z0**2))
            theta = torch.linspace(0, 2*np.pi, 361, device=device)
            r = torch.linspace(0, r_max, 200, device=device)
            R, Θ = torch.meshgrid(r, theta, indexing='ij')
            X = R*torch.cos(Θ); Y = R*torch.sin(Θ); Z = torch.full_like(X, z0)
            pts_flat = torch.stack([X.reshape(-1), Y.reshape(-1), Z.reshape(-1)], 1)

            # Predictions
            u_pred = model(pts_flat).reshape(R.shape).cpu().numpy()
            u_exact = exact_solution(pts_flat[:,0], pts_flat[:,1], pts_flat[:,2]).reshape(R.shape).cpu().numpy()
            u_resid = np.abs(u_exact - u_pred)

            # Title with lambda
            lambda_val = model.lambda_param.mean().item()

            fig, axs = plt.subplots(1, 3, subplot_kw={'projection': 'polar'}, figsize=(12, 4))
            fig.suptitle(f'Equatorial Slice z={z0:.2f} | λ ≈ {lambda_val:.4f}', fontsize=12, y=1.1)

            # for ax, data, ttl in zip(axs, [u_pred, u_exact, u_resid], ['pred', 'exact', 'abs error']):
            #     c = ax.contourf(Θ.cpu(), R.cpu(), data, levels=50)
            #     ax.text(0.5, 1.12, ttl, transform=ax.transAxes, ha='center', va='center', fontsize=10)
            #     fig.colorbar(c, ax=ax, shrink=0.8)

            for ax, data, ttl in zip(axs, [u_pred, u_exact, u_resid], ['pred', 'exact', 'abs error']):
                if ttl == 'abs error':
                    c = ax.contourf(Θ.cpu(), R.cpu(), data, levels=50, cmap='magma')
                else:
                    c = ax.contourf(Θ.cpu(), R.cpu(), data, levels=50)
                ax.text(0.5, 1.12, ttl, transform=ax.transAxes, ha='center', va='center', fontsize=10)
                fig.colorbar(c, ax=ax, shrink=0.8)

            plt.subplots_adjust(wspace=0.5)
            plt.tight_layout()


        # ---- 3) meridional slice x=0 (y–z plane) ------------
        y = torch.linspace(-1,1,301, device=device)
        z = torch.linspace(-1,1,301, device=device)
        Y, Z = torch.meshgrid(y, z, indexing='ij')
        mask = Y**2 + Z**2 <= 1.0
        X0 = torch.zeros_like(Y)
        pts_plane = torch.stack([X0[mask], Y[mask], Z[mask]], 1)
        u_pred_plane = model(pts_plane).cpu().numpy()
        u_exact_plane = exact_solution(pts_plane[:,0], pts_plane[:,1], pts_plane[:,2]).cpu().numpy()

        # put back into full grid with NaNs outside ball
        U_pred_grid = np.full(Y.shape, np.nan); U_exact_grid = np.full_like(U_pred_grid, np.nan)
        U_pred_grid[mask.cpu().numpy()]  = u_pred_plane
        U_exact_grid[mask.cpu().numpy()] = u_exact_plane

        fig,axs = plt.subplots(1,2,figsize=(8,4))
        for ax, data, ttl in zip(axs,[U_pred_grid,U_exact_grid],['pred','exact']):
            im = ax.imshow(data, origin='lower', extent=[-1,1,-1,1], cmap='seismic')
            ax.set_title(f'{ttl}  slice x=0')
            fig.colorbar(im, ax=ax, shrink=0.8)

        plt.subplots_adjust(wspace=0.4)
        plt.tight_layout()
        plt.show()

# %%
if __name__ == '__main__':
    torch.manual_seed(345)
    model = Experiment()
    model.to(model.device)
    print(f"Using device: {model.device}")
    print(f"Parameters: {sum(p.numel() for p in model.parameters())}")

    # Set loss weights
    model.w_int  = 1000.0   # Interior PDE loss weight
    model.w_bc   = 1.0    # Boundary condition loss weight
    model.w_data = 1.0  # Data loss weight
    model.w_norm = 1.0  # Normalization loss weight

    # Run training
    # pretrain(model, epochs=100)
    train_full(model, epochs=30000, lr=1e-2)
# Out:
# Using device: cuda:0
# Parameters: 1042
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py:823: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:180.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 0: Total Loss=2.95e+00, PDE=7.00e-04, BC=1.16e-02, DATA=2.94e-02, λ=0.0487
# Epoch 100: Total Loss=1.03e+00, PDE=2.52e-03, BC=1.85e-02, DATA=9.85e-03, λ=1.3786
# Epoch 200: Total Loss=1.12e+00, PDE=3.68e-03, BC=1.73e-02, DATA=1.07e-02, λ=1.5032
# Epoch 300: Total Loss=1.19e+00, PDE=4.61e-03, BC=1.68e-02, DATA=1.13e-02, λ=1.6167
# Epoch 400: Total Loss=1.20e+00, PDE=3.46e-03, BC=1.27e-02, DATA=1.15e-02, λ=1.6280
# Epoch 500: Total Loss=1.39e+00, PDE=4.50e-03, BC=1.40e-02, DATA=1.33e-02, λ=1.7311
# Epoch 600: Total Loss=1.08e+00, PDE=6.45e-03, BC=1.31e-02, DATA=1.00e-02, λ=2.0164
# Epoch 700: Total Loss=9.49e-01, PDE=1.60e-02, BC=1.26e-02, DATA=7.76e-03, λ=2.8023
# Epoch 800: Total Loss=5.90e-01, PDE=8.26e-03, BC=7.64e-03, DATA=5.00e-03, λ=3.4448
# Epoch 900: Total Loss=4.24e-01, PDE=1.08e-02, BC=5.42e-03, DATA=3.11e-03, λ=3.6413
# Epoch 1000: Total Loss=4.94e-01, PDE=1.66e-02, BC=6.01e-03, DATA=3.21e-03, λ=3.7425
# Epoch 1100: Total Loss=4.06e-01, PDE=1.27e-02, BC=5.70e-03, DATA=2.73e-03, λ=3.7600
# Epoch 1200: Total Loss=5.52e-01, PDE=2.58e-02, BC=5.97e-03, DATA=2.87e-03, λ=3.8029
# Epoch 1300: Total Loss=3.76e-01, PDE=1.09e-02, BC=4.55e-03, DATA=2.62e-03, λ=3.7969
# Epoch 1400: Total Loss=3.45e-01, PDE=1.16e-02, BC=4.77e-03, DATA=2.25e-03, λ=3.8376
# Epoch 1500: Total Loss=3.62e-01, PDE=9.13e-03, BC=4.10e-03, DATA=2.66e-03, λ=3.8450
# Epoch 1600: Total Loss=4.33e-01, PDE=1.68e-02, BC=3.85e-03, DATA=2.61e-03, λ=3.8379
# Epoch 1700: Total Loss=3.51e-01, PDE=1.34e-02, BC=4.73e-03, DATA=2.13e-03, λ=3.8735
# Epoch 1800: Total Loss=3.55e-01, PDE=1.37e-02, BC=4.32e-03, DATA=2.14e-03, λ=3.9061
# Epoch 1900: Total Loss=3.42e-01, PDE=1.08e-02, BC=4.13e-03, DATA=2.30e-03, λ=3.9088
# Epoch 2000: Total Loss=3.92e-01, PDE=1.51e-02, BC=4.46e-03, DATA=2.36e-03, λ=3.9283
# Epoch 2100: Total Loss=3.50e-01, PDE=1.52e-02, BC=3.51e-03, DATA=1.94e-03, λ=3.9100
# Epoch 2200: Total Loss=3.48e-01, PDE=1.19e-02, BC=3.99e-03, DATA=2.24e-03, λ=3.9520
# Epoch 2300: Total Loss=3.28e-01, PDE=1.35e-02, BC=2.66e-03, DATA=1.90e-03, λ=3.9621
# Epoch 2400: Total Loss=3.00e-01, PDE=1.21e-02, BC=4.41e-03, DATA=1.74e-03, λ=3.9476
# Epoch 2500: Total Loss=2.76e-01, PDE=9.42e-03, BC=3.16e-03, DATA=1.79e-03, λ=3.9603
# Epoch 2600: Total Loss=2.50e-01, PDE=9.58e-03, BC=3.33e-03, DATA=1.51e-03, λ=3.9929
# Epoch 2700: Total Loss=2.56e-01, PDE=1.18e-02, BC=2.70e-03, DATA=1.35e-03, λ=3.9915
# Epoch 2800: Total Loss=2.68e-01, PDE=1.16e-02, BC=2.55e-03, DATA=1.49e-03, λ=4.0041
# Epoch 2900: Total Loss=2.70e-01, PDE=1.20e-02, BC=3.15e-03, DATA=1.47e-03, λ=4.0084
# Epoch 3000: Total Loss=2.64e-01, PDE=1.09e-02, BC=2.81e-03, DATA=1.52e-03, λ=4.0089
# Epoch 3100: Total Loss=2.86e-01, PDE=1.38e-02, BC=3.01e-03, DATA=1.45e-03, λ=4.0203
# Epoch 3200: Total Loss=2.76e-01, PDE=1.13e-02, BC=2.90e-03, DATA=1.60e-03, λ=4.0301
# Epoch 3300: Total Loss=2.47e-01, PDE=9.68e-03, BC=3.10e-03, DATA=1.47e-03, λ=4.0320
# Epoch 3400: Total Loss=2.35e-01, PDE=1.20e-02, BC=2.42e-03, DATA=1.13e-03, λ=4.0349
# Epoch 3500: Total Loss=2.51e-01, PDE=1.02e-02, BC=2.49e-03, DATA=1.47e-03, λ=4.0638
# Epoch 3600: Total Loss=2.86e-01, PDE=1.38e-02, BC=2.70e-03, DATA=1.45e-03, λ=4.0546
# Epoch 3700: Total Loss=2.40e-01, PDE=1.23e-02, BC=2.86e-03, DATA=1.14e-03, λ=4.0673
# Epoch 3800: Total Loss=4.31e-01, PDE=2.91e-02, BC=2.44e-03, DATA=1.38e-03, λ=4.0587
# Epoch 3900: Total Loss=2.37e-01, PDE=1.25e-02, BC=2.09e-03, DATA=1.09e-03, λ=4.0699
# Epoch 4000: Total Loss=1.93e-01, PDE=7.33e-03, BC=2.32e-03, DATA=1.17e-03, λ=4.0860
# Epoch 4100: Total Loss=2.73e-01, PDE=1.63e-02, BC=1.46e-03, DATA=1.09e-03, λ=4.0828
# Epoch 4200: Total Loss=2.44e-01, PDE=1.32e-02, BC=2.48e-03, DATA=1.09e-03, λ=4.1101
# Epoch 4300: Total Loss=1.97e-01, PDE=8.32e-03, BC=2.25e-03, DATA=1.12e-03, λ=4.1100
# Epoch 4400: Total Loss=1.75e-01, PDE=7.94e-03, BC=1.99e-03, DATA=9.36e-04, λ=4.1176
# Epoch 4500: Total Loss=2.05e-01, PDE=9.75e-03, BC=2.08e-03, DATA=1.05e-03, λ=4.1191
# Epoch 4600: Total Loss=2.28e-01, PDE=1.10e-02, BC=1.74e-03, DATA=1.16e-03, λ=4.1215
# Epoch 4700: Total Loss=2.00e-01, PDE=1.09e-02, BC=1.58e-03, DATA=9.00e-04, λ=4.1263
# Epoch 4800: Total Loss=1.76e-01, PDE=8.74e-03, BC=1.87e-03, DATA=8.67e-04, λ=4.1303
# Epoch 4900: Total Loss=1.90e-01, PDE=9.45e-03, BC=2.29e-03, DATA=9.36e-04, λ=4.1251
# Epoch 5000: Total Loss=1.74e-01, PDE=8.16e-03, BC=1.56e-03, DATA=9.13e-04, λ=4.1297
# Epoch 5100: Total Loss=1.84e-01, PDE=9.88e-03, BC=1.38e-03, DATA=8.36e-04, λ=4.1485
# Epoch 5200: Total Loss=1.53e-01, PDE=7.38e-03, BC=1.50e-03, DATA=7.73e-04, λ=4.1554
# Epoch 5300: Total Loss=1.85e-01, PDE=9.78e-03, BC=1.88e-03, DATA=8.48e-04, λ=4.1618
# Epoch 5400: Total Loss=1.61e-01, PDE=8.28e-03, BC=1.36e-03, DATA=7.71e-04, λ=4.1647
# Epoch 5500: Total Loss=1.58e-01, PDE=7.41e-03, BC=1.77e-03, DATA=8.16e-04, λ=4.1535
# Epoch 5600: Total Loss=1.90e-01, PDE=1.11e-02, BC=1.90e-03, DATA=7.73e-04, λ=4.1873
# Epoch 5700: Total Loss=1.35e-01, PDE=6.46e-03, BC=1.46e-03, DATA=6.94e-04, λ=4.1669
# Epoch 5800: Total Loss=1.55e-01, PDE=7.39e-03, BC=1.30e-03, DATA=7.95e-04, λ=4.1711
# Epoch 5900: Total Loss=1.53e-01, PDE=7.12e-03, BC=1.44e-03, DATA=8.00e-04, λ=4.1938
# Epoch 6000: Total Loss=2.05e-01, PDE=1.43e-02, BC=1.64e-03, DATA=6.13e-04, λ=4.2062
# Epoch 6100: Total Loss=1.74e-01, PDE=1.01e-02, BC=1.29e-03, DATA=7.19e-04, λ=4.2016
# Epoch 6200: Total Loss=1.35e-01, PDE=7.00e-03, BC=1.37e-03, DATA=6.37e-04, λ=4.2097
# Epoch 6300: Total Loss=1.65e-01, PDE=1.02e-02, BC=1.21e-03, DATA=6.17e-04, λ=4.2031
# Epoch 6400: Total Loss=1.10e-01, PDE=5.62e-03, BC=1.22e-03, DATA=5.28e-04, λ=4.2158
# Epoch 6500: Total Loss=1.67e-01, PDE=1.14e-02, BC=8.40e-04, DATA=5.25e-04, λ=4.2024
# Epoch 6600: Total Loss=1.61e-01, PDE=1.14e-02, BC=1.05e-03, DATA=4.61e-04, λ=4.2228
# Epoch 6700: Total Loss=1.19e-01, PDE=6.98e-03, BC=1.18e-03, DATA=4.77e-04, λ=4.2492
# Epoch 6800: Total Loss=2.06e-01, PDE=1.49e-02, BC=6.60e-04, DATA=5.59e-04, λ=4.2242
# Epoch 6900: Total Loss=1.49e-01, PDE=9.97e-03, BC=7.80e-04, DATA=4.85e-04, λ=4.2367
# Epoch 7000: Total Loss=1.46e-01, PDE=8.40e-03, BC=1.07e-03, DATA=6.12e-04, λ=4.2375
# Epoch 7100: Total Loss=1.29e-01, PDE=8.52e-03, BC=8.59e-04, DATA=4.33e-04, λ=4.2563
# Epoch 7200: Total Loss=1.02e-01, PDE=5.66e-03, BC=8.72e-04, DATA=4.47e-04, λ=4.2468
# Epoch 7300: Total Loss=1.24e-01, PDE=7.67e-03, BC=6.97e-04, DATA=4.66e-04, λ=4.2549
# Epoch 7400: Total Loss=9.53e-02, PDE=4.87e-03, BC=7.21e-04, DATA=4.59e-04, λ=4.2663
# Epoch 7500: Total Loss=1.56e-01, PDE=1.07e-02, BC=1.09e-03, DATA=4.77e-04, λ=4.2725
# Epoch 7600: Total Loss=1.18e-01, PDE=8.02e-03, BC=9.34e-04, DATA=3.64e-04, λ=4.2770
# Epoch 7700: Total Loss=1.04e-01, PDE=6.52e-03, BC=9.34e-04, DATA=3.79e-04, λ=4.2633
# Epoch 7800: Total Loss=9.64e-02, PDE=5.72e-03, BC=8.98e-04, DATA=3.83e-04, λ=4.2851
# Epoch 7900: Total Loss=9.84e-02, PDE=5.94e-03, BC=7.07e-04, DATA=3.83e-04, λ=4.2716
# Epoch 8000: Total Loss=1.13e-01, PDE=6.95e-03, BC=8.64e-04, DATA=4.21e-04, λ=4.2854
# Epoch 8100: Total Loss=9.40e-02, PDE=5.48e-03, BC=7.52e-04, DATA=3.85e-04, λ=4.2857
# Epoch 8200: Total Loss=1.08e-01, PDE=7.22e-03, BC=8.24e-04, DATA=3.45e-04, λ=4.2920
# Epoch 8300: Total Loss=1.08e-01, PDE=6.97e-03, BC=7.39e-04, DATA=3.75e-04, λ=4.2868
# Epoch 8400: Total Loss=1.13e-01, PDE=7.46e-03, BC=5.05e-04, DATA=3.77e-04, λ=4.2855
# Epoch 8500: Total Loss=1.29e-01, PDE=9.24e-03, BC=6.37e-04, DATA=3.64e-04, λ=4.3029
# Epoch 8600: Total Loss=1.15e-01, PDE=8.59e-03, BC=5.58e-04, DATA=2.83e-04, λ=4.2972
# Epoch 8700: Total Loss=1.08e-01, PDE=7.07e-03, BC=7.05e-04, DATA=3.66e-04, λ=4.2962
# Epoch 8800: Total Loss=1.03e-01, PDE=6.96e-03, BC=7.48e-04, DATA=3.27e-04, λ=4.3027
# Epoch 8900: Total Loss=7.82e-02, PDE=4.13e-03, BC=7.53e-04, DATA=3.62e-04, λ=4.2606
# Epoch 9000: Total Loss=7.87e-02, PDE=4.63e-03, BC=5.89e-04, DATA=3.17e-04, λ=4.3057
# Epoch 9100: Total Loss=7.57e-02, PDE=4.58e-03, BC=5.04e-04, DATA=2.94e-04, λ=4.3192
# Epoch 9200: Total Loss=1.04e-01, PDE=7.34e-03, BC=5.42e-04, DATA=3.01e-04, λ=4.3215
# Epoch 9300: Total Loss=1.21e-01, PDE=8.22e-03, BC=8.38e-04, DATA=3.75e-04, λ=4.3139
# Epoch 9400: Total Loss=1.26e-01, PDE=9.68e-03, BC=6.91e-04, DATA=2.86e-04, λ=4.3197
# Epoch 9500: Total Loss=7.34e-02, PDE=4.25e-03, BC=5.07e-04, DATA=3.04e-04, λ=4.3139
# Epoch 9600: Total Loss=9.29e-02, PDE=6.97e-03, BC=3.78e-04, DATA=2.29e-04, λ=4.3214
# Epoch 9700: Total Loss=1.81e-01, PDE=1.55e-02, BC=3.16e-04, DATA=2.53e-04, λ=4.3144
# Epoch 9800: Total Loss=6.83e-02, PDE=4.84e-03, BC=3.96e-04, DATA=1.95e-04, λ=4.3252
# Epoch 9900: Total Loss=1.13e-01, PDE=8.61e-03, BC=4.91e-04, DATA=2.61e-04, λ=4.3191
# Epoch 10000: Total Loss=6.22e-02, PDE=4.18e-03, BC=5.66e-04, DATA=1.99e-04, λ=4.3244
# Epoch 10100: Total Loss=7.68e-02, PDE=5.06e-03, BC=5.14e-04, DATA=2.57e-04, λ=4.3326
# Epoch 10200: Total Loss=8.64e-02, PDE=5.82e-03, BC=7.11e-04, DATA=2.74e-04, λ=4.3158
# Epoch 10300: Total Loss=6.38e-02, PDE=4.44e-03, BC=4.53e-04, DATA=1.90e-04, λ=4.3331
# Epoch 10400: Total Loss=7.36e-02, PDE=5.11e-03, BC=4.49e-04, DATA=2.21e-04, λ=4.3378
# Epoch 10500: Total Loss=7.73e-02, PDE=5.19e-03, BC=4.93e-04, DATA=2.50e-04, λ=4.3441
# Epoch 10600: Total Loss=7.68e-02, PDE=5.32e-03, BC=4.58e-04, DATA=2.31e-04, λ=4.3361
# Epoch 10700: Total Loss=7.74e-02, PDE=5.51e-03, BC=4.71e-04, DATA=2.19e-04, λ=4.3319
# Epoch 10800: Total Loss=1.06e-01, PDE=8.07e-03, BC=6.17e-04, DATA=2.49e-04, λ=4.3376
# Epoch 10900: Total Loss=6.77e-02, PDE=4.64e-03, BC=5.76e-04, DATA=2.08e-04, λ=4.3432
# Epoch 11000: Total Loss=7.25e-02, PDE=4.60e-03, BC=4.30e-04, DATA=2.61e-04, λ=4.3308
# Epoch 11100: Total Loss=6.51e-02, PDE=4.49e-03, BC=5.17e-04, DATA=1.97e-04, λ=4.3421
# Epoch 11200: Total Loss=1.06e-01, PDE=8.13e-03, BC=5.73e-04, DATA=2.38e-04, λ=4.3434
# Epoch 11300: Total Loss=9.58e-02, PDE=7.34e-03, BC=5.77e-04, DATA=2.19e-04, λ=4.3426
# Epoch 11400: Total Loss=5.73e-02, PDE=3.59e-03, BC=4.26e-04, DATA=2.09e-04, λ=4.3407
# Epoch 11500: Total Loss=8.65e-02, PDE=5.90e-03, BC=5.08e-04, DATA=2.69e-04, λ=4.3313
# Epoch 11600: Total Loss=8.37e-02, PDE=5.41e-03, BC=5.63e-04, DATA=2.90e-04, λ=4.3499
# Epoch 11700: Total Loss=1.09e-01, PDE=8.24e-03, BC=6.58e-04, DATA=2.61e-04, λ=4.3471
# Epoch 11800: Total Loss=9.72e-02, PDE=7.69e-03, BC=4.19e-04, DATA=1.99e-04, λ=4.3348
# Epoch 11900: Total Loss=1.04e-01, PDE=8.39e-03, BC=3.69e-04, DATA=1.96e-04, λ=4.3400
# Epoch 12000: Total Loss=6.38e-02, PDE=4.43e-03, BC=5.60e-04, DATA=1.90e-04, λ=4.3486
# Epoch 12100: Total Loss=7.09e-02, PDE=4.65e-03, BC=4.93e-04, DATA=2.39e-04, λ=4.3267
# Epoch 12200: Total Loss=1.09e-01, PDE=8.95e-03, BC=3.24e-04, DATA=1.93e-04, λ=4.3436
# Epoch 12300: Total Loss=6.82e-02, PDE=4.77e-03, BC=4.16e-04, DATA=2.01e-04, λ=4.3630
# Epoch 12400: Total Loss=6.00e-02, PDE=3.59e-03, BC=4.65e-04, DATA=2.36e-04, λ=4.3527
# Epoch 12500: Total Loss=8.14e-02, PDE=6.18e-03, BC=4.04e-04, DATA=1.92e-04, λ=4.3466
# Epoch 12600: Total Loss=8.91e-02, PDE=6.84e-03, BC=3.90e-04, DATA=2.04e-04, λ=4.3567
# Epoch 12700: Total Loss=8.84e-02, PDE=6.79e-03, BC=4.32e-04, DATA=2.00e-04, λ=4.3441
# Epoch 12800: Total Loss=8.76e-02, PDE=6.57e-03, BC=5.49e-04, DATA=2.14e-04, λ=4.3474
# Epoch 12900: Total Loss=6.44e-02, PDE=4.71e-03, BC=3.81e-04, DATA=1.69e-04, λ=4.3517
# Epoch 13000: Total Loss=8.57e-02, PDE=6.88e-03, BC=3.95e-04, DATA=1.65e-04, λ=4.3504
# Epoch 13100: Total Loss=7.32e-02, PDE=5.32e-03, BC=5.07e-04, DATA=1.95e-04, λ=4.3594
# Epoch 13200: Total Loss=9.51e-02, PDE=7.51e-03, BC=2.87e-04, DATA=1.97e-04, λ=4.3498
# Epoch 13300: Total Loss=6.68e-02, PDE=4.32e-03, BC=4.52e-04, DATA=2.32e-04, λ=4.3568
# Epoch 13400: Total Loss=1.07e-01, PDE=8.69e-03, BC=3.01e-04, DATA=1.99e-04, λ=4.3446
# Epoch 13500: Total Loss=5.89e-02, PDE=3.74e-03, BC=3.91e-04, DATA=2.11e-04, λ=4.3471
# Epoch 13600: Total Loss=1.06e-01, PDE=8.10e-03, BC=6.04e-04, DATA=2.41e-04, λ=4.3517
# Epoch 13700: Total Loss=7.18e-02, PDE=4.41e-03, BC=5.11e-04, DATA=2.72e-04, λ=4.3587
# Epoch 13800: Total Loss=7.50e-02, PDE=5.79e-03, BC=5.03e-04, DATA=1.66e-04, λ=4.3626
# Epoch 13900: Total Loss=5.54e-02, PDE=3.72e-03, BC=3.89e-04, DATA=1.78e-04, λ=4.3601
# Epoch 14000: Total Loss=5.95e-02, PDE=4.10e-03, BC=4.13e-04, DATA=1.81e-04, λ=4.3622
# Epoch 14100: Total Loss=1.40e-01, PDE=1.19e-02, BC=4.05e-04, DATA=2.10e-04, λ=4.3376
# Epoch 14200: Total Loss=6.28e-02, PDE=4.65e-03, BC=4.23e-04, DATA=1.59e-04, λ=4.3627
# Epoch 14300: Total Loss=8.35e-02, PDE=6.33e-03, BC=5.06e-04, DATA=1.97e-04, λ=4.3535
# Epoch 14400: Total Loss=5.23e-02, PDE=2.84e-03, BC=4.11e-04, DATA=2.35e-04, λ=4.3547
# Epoch 14500: Total Loss=7.47e-02, PDE=5.24e-03, BC=4.25e-04, DATA=2.19e-04, λ=4.3608
# Epoch 14600: Total Loss=1.75e-01, PDE=1.50e-02, BC=7.09e-04, DATA=2.43e-04, λ=4.3682
# Epoch 14700: Total Loss=6.29e-02, PDE=4.30e-03, BC=3.55e-04, DATA=1.96e-04, λ=4.3595
# Epoch 14800: Total Loss=5.36e-02, PDE=3.39e-03, BC=4.02e-04, DATA=1.93e-04, λ=4.3640
# Epoch 14900: Total Loss=1.58e-01, PDE=1.36e-02, BC=5.01e-04, DATA=2.21e-04, λ=4.3585
# Epoch 15000: Total Loss=1.13e-01, PDE=8.29e-03, BC=6.42e-04, DATA=2.90e-04, λ=4.3580
# Epoch 15100: Total Loss=1.31e-01, PDE=1.11e-02, BC=2.84e-04, DATA=1.96e-04, λ=4.3520
# Epoch 15200: Total Loss=1.21e-01, PDE=9.57e-03, BC=6.37e-04, DATA=2.44e-04, λ=4.3560
# Epoch 15300: Total Loss=8.78e-02, PDE=7.01e-03, BC=4.45e-04, DATA=1.73e-04, λ=4.3661
# Epoch 15400: Total Loss=6.27e-02, PDE=4.47e-03, BC=3.96e-04, DATA=1.76e-04, λ=4.3621
# Epoch 15500: Total Loss=1.07e-01, PDE=8.76e-03, BC=2.88e-04, DATA=1.89e-04, λ=4.3572
# Epoch 15600: Total Loss=1.42e-01, PDE=1.22e-02, BC=2.74e-04, DATA=1.98e-04, λ=4.3507
# Epoch 15700: Total Loss=7.13e-02, PDE=5.23e-03, BC=3.33e-04, DATA=1.86e-04, λ=4.3601
# Epoch 15800: Total Loss=6.71e-02, PDE=4.91e-03, BC=4.45e-04, DATA=1.76e-04, λ=4.3677
# Epoch 15900: Total Loss=6.47e-02, PDE=4.50e-03, BC=3.69e-04, DATA=1.93e-04, λ=4.3683
# Epoch 16000: Total Loss=1.09e-01, PDE=8.41e-03, BC=5.47e-04, DATA=2.42e-04, λ=4.3508
# Epoch 16100: Total Loss=5.83e-02, PDE=4.08e-03, BC=3.75e-04, DATA=1.72e-04, λ=4.3616
# Epoch 16200: Total Loss=1.29e-01, PDE=1.03e-02, BC=2.91e-04, DATA=2.55e-04, λ=4.3522
# Epoch 16300: Total Loss=6.14e-02, PDE=4.51e-03, BC=3.49e-04, DATA=1.60e-04, λ=4.3654
# Epoch 16400: Total Loss=4.94e-02, PDE=3.31e-03, BC=4.08e-04, DATA=1.60e-04, λ=4.3576
# Epoch 16500: Total Loss=7.53e-02, PDE=5.42e-03, BC=5.53e-04, DATA=2.06e-04, λ=4.3555
# Epoch 16600: Total Loss=7.18e-02, PDE=5.77e-03, BC=3.09e-04, DATA=1.38e-04, λ=4.3620
# Epoch 16700: Total Loss=6.52e-02, PDE=4.66e-03, BC=3.30e-04, DATA=1.83e-04, λ=4.3648
# Epoch 16800: Total Loss=6.69e-02, PDE=4.34e-03, BC=4.69e-04, DATA=2.30e-04, λ=4.3654
# Epoch 16900: Total Loss=6.53e-02, PDE=4.67e-03, BC=3.60e-04, DATA=1.83e-04, λ=4.3593
# Epoch 17000: Total Loss=5.60e-02, PDE=3.83e-03, BC=4.12e-04, DATA=1.73e-04, λ=4.3543
# Epoch 17100: Total Loss=6.54e-02, PDE=4.42e-03, BC=3.68e-04, DATA=2.08e-04, λ=4.3603
# Epoch 17200: Total Loss=5.75e-02, PDE=3.87e-03, BC=3.44e-04, DATA=1.84e-04, λ=4.3637
# Epoch 17300: Total Loss=6.43e-02, PDE=4.48e-03, BC=3.11e-04, DATA=1.92e-04, λ=4.3680
# Epoch 17400: Total Loss=8.43e-02, PDE=6.67e-03, BC=5.60e-04, DATA=1.71e-04, λ=4.3633
# Epoch 17500: Total Loss=7.84e-02, PDE=6.14e-03, BC=3.36e-04, DATA=1.66e-04, λ=4.3746
# Epoch 17600: Total Loss=6.01e-02, PDE=3.83e-03, BC=4.13e-04, DATA=2.14e-04, λ=4.3520
# Epoch 17700: Total Loss=5.69e-02, PDE=3.61e-03, BC=5.18e-04, DATA=2.02e-04, λ=4.3621
# Epoch 17800: Total Loss=6.12e-02, PDE=3.98e-03, BC=4.67e-04, DATA=2.10e-04, λ=4.3536
# Epoch 17900: Total Loss=4.95e-02, PDE=3.09e-03, BC=4.13e-04, DATA=1.82e-04, λ=4.3660
# Epoch 18000: Total Loss=1.64e-01, PDE=1.35e-02, BC=6.59e-04, DATA=2.88e-04, λ=4.3655
# Epoch 18100: Total Loss=7.11e-02, PDE=5.34e-03, BC=4.92e-04, DATA=1.72e-04, λ=4.3643
# Epoch 18200: Total Loss=5.02e-02, PDE=3.30e-03, BC=3.28e-04, DATA=1.69e-04, λ=4.3701
# Epoch 18300: Total Loss=1.31e-01, PDE=1.04e-02, BC=5.53e-04, DATA=2.68e-04, λ=4.3593
# Epoch 18400: Total Loss=5.62e-02, PDE=3.88e-03, BC=4.35e-04, DATA=1.69e-04, λ=4.3676
# Epoch 18500: Total Loss=1.19e-01, PDE=1.04e-02, BC=2.39e-04, DATA=1.55e-04, λ=4.3654
# Epoch 18600: Total Loss=3.71e-01, PDE=3.41e-02, BC=3.91e-04, DATA=2.94e-04, λ=4.3121
# Epoch 18700: Total Loss=7.17e-02, PDE=5.32e-03, BC=4.21e-04, DATA=1.81e-04, λ=4.3643
# Epoch 18800: Total Loss=8.44e-02, PDE=6.37e-03, BC=5.10e-04, DATA=2.02e-04, λ=4.3781
# Epoch 18900: Total Loss=9.69e-02, PDE=7.69e-03, BC=4.93e-04, DATA=1.95e-04, λ=4.3776
# Epoch 19000: Total Loss=9.09e-02, PDE=7.47e-03, BC=5.98e-04, DATA=1.56e-04, λ=4.3680
# Epoch 19100: Total Loss=5.97e-02, PDE=4.06e-03, BC=4.27e-04, DATA=1.87e-04, λ=4.3759
# Epoch 19200: Total Loss=8.18e-02, PDE=6.23e-03, BC=5.03e-04, DATA=1.89e-04, λ=4.3625
# Epoch 19300: Total Loss=1.70e-01, PDE=1.49e-02, BC=2.44e-04, DATA=2.10e-04, λ=4.3536
# Epoch 19400: Total Loss=4.61e-02, PDE=2.60e-03, BC=3.84e-04, DATA=1.97e-04, λ=4.3648
# Epoch 19500: Total Loss=8.24e-02, PDE=6.25e-03, BC=3.56e-04, DATA=1.96e-04, λ=4.3690
# Epoch 19600: Total Loss=1.55e-01, PDE=1.39e-02, BC=2.68e-04, DATA=1.52e-04, λ=4.3494
# Epoch 19700: Total Loss=4.76e-02, PDE=2.89e-03, BC=4.02e-04, DATA=1.83e-04, λ=4.3659
# Epoch 19800: Total Loss=5.80e-02, PDE=4.11e-03, BC=3.34e-04, DATA=1.67e-04, λ=4.3648
# Epoch 19900: Total Loss=2.09e-01, PDE=1.82e-02, BC=7.10e-04, DATA=2.66e-04, λ=4.3740
# Epoch 20000: Total Loss=9.65e-02, PDE=8.06e-03, BC=3.56e-04, DATA=1.55e-04, λ=4.3661
# Epoch 20100: Total Loss=3.41e-01, PDE=2.87e-02, BC=1.12e-03, DATA=5.32e-04, λ=4.3421
# Epoch 20200: Total Loss=5.01e-02, PDE=2.94e-03, BC=4.20e-04, DATA=2.02e-04, λ=4.3680
# Epoch 20300: Total Loss=6.87e-02, PDE=4.76e-03, BC=4.54e-04, DATA=2.06e-04, λ=4.3774
# Epoch 20400: Total Loss=5.41e-02, PDE=3.82e-03, BC=3.93e-04, DATA=1.56e-04, λ=4.3735
# Epoch 20500: Total Loss=1.32e-01, PDE=1.09e-02, BC=5.62e-04, DATA=2.26e-04, λ=4.3692
# Epoch 20600: Total Loss=7.73e-02, PDE=6.04e-03, BC=3.32e-04, DATA=1.66e-04, λ=4.3671
# Epoch 20700: Total Loss=1.07e-01, PDE=8.65e-03, BC=5.05e-04, DATA=1.96e-04, λ=4.3793
# Epoch 20800: Total Loss=1.70e-01, PDE=1.45e-02, BC=6.06e-04, DATA=2.49e-04, λ=4.3780
# Epoch 20900: Total Loss=5.96e-02, PDE=4.05e-03, BC=3.69e-04, DATA=1.88e-04, λ=4.3624
# Epoch 21000: Total Loss=5.27e-02, PDE=3.20e-03, BC=4.39e-04, DATA=2.02e-04, λ=4.3706
# Epoch 21100: Total Loss=1.16e-01, PDE=9.74e-03, BC=2.51e-04, DATA=1.81e-04, λ=4.3624
# Epoch 21200: Total Loss=6.45e-02, PDE=4.65e-03, BC=4.16e-04, DATA=1.76e-04, λ=4.3731
# Epoch 21300: Total Loss=2.42e-01, PDE=2.18e-02, BC=2.21e-04, DATA=2.41e-04, λ=4.3459
# Epoch 21400: Total Loss=5.95e-02, PDE=3.93e-03, BC=4.33e-04, DATA=1.97e-04, λ=4.3672
# Epoch 21500: Total Loss=6.82e-02, PDE=4.99e-03, BC=3.63e-04, DATA=1.80e-04, λ=4.3661
# Epoch 21600: Total Loss=1.06e-01, PDE=8.30e-03, BC=5.83e-04, DATA=2.19e-04, λ=4.3753
# Epoch 21700: Total Loss=5.36e-02, PDE=3.87e-03, BC=3.63e-04, DATA=1.45e-04, λ=4.3787
# Epoch 21800: Total Loss=5.44e-02, PDE=3.33e-03, BC=3.93e-04, DATA=2.06e-04, λ=4.3633
# Epoch 21900: Total Loss=6.00e-02, PDE=4.03e-03, BC=4.65e-04, DATA=1.92e-04, λ=4.3792
# Epoch 22000: Total Loss=5.55e-02, PDE=3.66e-03, BC=3.65e-04, DATA=1.86e-04, λ=4.3636
# Epoch 22100: Total Loss=1.30e-01, PDE=1.07e-02, BC=3.46e-04, DATA=2.23e-04, λ=4.3645
# Epoch 22200: Total Loss=7.38e-02, PDE=5.49e-03, BC=3.23e-04, DATA=1.86e-04, λ=4.3658
# Epoch 22300: Total Loss=6.92e-02, PDE=5.19e-03, BC=3.27e-04, DATA=1.71e-04, λ=4.3662
# Epoch 22400: Total Loss=1.66e-01, PDE=1.46e-02, BC=2.58e-04, DATA=1.94e-04, λ=4.3574
# Epoch 22500: Total Loss=6.05e-02, PDE=4.06e-03, BC=4.20e-04, DATA=1.94e-04, λ=4.3763
# Epoch 22600: Total Loss=1.30e-01, PDE=1.07e-02, BC=5.54e-04, DATA=2.24e-04, λ=4.3757
# Epoch 22700: Total Loss=1.48e-01, PDE=1.32e-02, BC=2.19e-04, DATA=1.62e-04, λ=4.3688
# Epoch 22800: Total Loss=5.44e-02, PDE=3.78e-03, BC=3.82e-04, DATA=1.62e-04, λ=4.3623
# Epoch 22900: Total Loss=5.84e-02, PDE=3.48e-03, BC=4.47e-04, DATA=2.31e-04, λ=4.3453
# Epoch 23000: Total Loss=8.33e-02, PDE=6.79e-03, BC=3.15e-04, DATA=1.51e-04, λ=4.3722
# Epoch 23100: Total Loss=9.16e-02, PDE=7.66e-03, BC=3.62e-04, DATA=1.46e-04, λ=4.3630
# Epoch 23200: Total Loss=7.24e-02, PDE=5.48e-03, BC=3.95e-04, DATA=1.72e-04, λ=4.3785
# Epoch 23300: Total Loss=7.00e-02, PDE=5.14e-03, BC=2.70e-04, DATA=1.84e-04, λ=4.3776
# Epoch 23400: Total Loss=5.24e-02, PDE=3.16e-03, BC=3.72e-04, DATA=2.04e-04, λ=4.3791
# Epoch 23500: Total Loss=6.60e-02, PDE=4.82e-03, BC=4.11e-04, DATA=1.74e-04, λ=4.3605
# Epoch 23600: Total Loss=5.95e-02, PDE=4.23e-03, BC=4.18e-04, DATA=1.68e-04, λ=4.3776
# Epoch 23700: Total Loss=4.35e-02, PDE=2.87e-03, BC=4.07e-04, DATA=1.44e-04, λ=4.3753
# Epoch 23800: Total Loss=5.06e-02, PDE=3.49e-03, BC=4.44e-04, DATA=1.53e-04, λ=4.3691
# Epoch 23900: Total Loss=8.01e-02, PDE=5.92e-03, BC=4.77e-04, DATA=2.04e-04, λ=4.3706
# Epoch 24000: Total Loss=6.24e-02, PDE=4.60e-03, BC=4.50e-04, DATA=1.59e-04, λ=4.3787
# Epoch 24100: Total Loss=1.68e-01, PDE=1.42e-02, BC=5.88e-04, DATA=2.46e-04, λ=4.3778
# Epoch 24200: Total Loss=3.83e-02, PDE=2.30e-03, BC=3.87e-04, DATA=1.49e-04, λ=4.3762
# Epoch 24300: Total Loss=5.61e-02, PDE=3.48e-03, BC=4.11e-04, DATA=2.09e-04, λ=4.3703
# Epoch 24400: Total Loss=6.17e-02, PDE=3.91e-03, BC=3.24e-04, DATA=2.23e-04, λ=4.3747
# Epoch 24500: Total Loss=9.97e-02, PDE=7.76e-03, BC=5.07e-04, DATA=2.17e-04, λ=4.3777
# Epoch 24600: Total Loss=7.09e-02, PDE=5.55e-03, BC=2.88e-04, DATA=1.51e-04, λ=4.3711
# Epoch 24700: Total Loss=6.95e-02, PDE=4.90e-03, BC=4.85e-04, DATA=2.01e-04, λ=4.3688
# Epoch 24800: Total Loss=7.14e-02, PDE=5.17e-03, BC=4.28e-04, DATA=1.93e-04, λ=4.3785
# Epoch 24900: Total Loss=4.98e-02, PDE=3.44e-03, BC=3.60e-04, DATA=1.50e-04, λ=4.3677
# Epoch 25000: Total Loss=5.03e-02, PDE=3.44e-03, BC=4.29e-04, DATA=1.55e-04, λ=4.3673
# Epoch 25100: Total Loss=7.67e-02, PDE=5.90e-03, BC=5.07e-04, DATA=1.72e-04, λ=4.3689
# Epoch 25200: Total Loss=4.60e-02, PDE=2.89e-03, BC=3.94e-04, DATA=1.68e-04, λ=4.3692
# Epoch 25300: Total Loss=5.28e-02, PDE=3.54e-03, BC=3.54e-04, DATA=1.71e-04, λ=4.3732
# Epoch 25400: Total Loss=4.15e-02, PDE=2.69e-03, BC=3.48e-04, DATA=1.42e-04, λ=4.3789
# Epoch 25500: Total Loss=1.44e-01, PDE=1.19e-02, BC=6.43e-04, DATA=2.52e-04, λ=4.3787
# Epoch 25600: Total Loss=6.17e-02, PDE=4.22e-03, BC=4.14e-04, DATA=1.90e-04, λ=4.3814
# Epoch 25700: Total Loss=6.91e-02, PDE=4.97e-03, BC=4.40e-04, DATA=1.90e-04, λ=4.3857
# Epoch 25800: Total Loss=7.03e-02, PDE=4.82e-03, BC=4.11e-04, DATA=2.17e-04, λ=4.3787
# Epoch 25900: Total Loss=5.66e-02, PDE=3.73e-03, BC=4.21e-04, DATA=1.89e-04, λ=4.3810
# Epoch 26000: Total Loss=8.55e-02, PDE=6.60e-03, BC=4.39e-04, DATA=1.91e-04, λ=4.3814
# Epoch 26100: Total Loss=7.75e-02, PDE=5.83e-03, BC=5.05e-04, DATA=1.88e-04, λ=4.3703
# Epoch 26200: Total Loss=1.06e-01, PDE=8.73e-03, BC=3.84e-04, DATA=1.84e-04, λ=4.3702
# Epoch 26300: Total Loss=8.76e-02, PDE=6.39e-03, BC=4.97e-04, DATA=2.32e-04, λ=4.3776
# Epoch 26400: Total Loss=5.46e-02, PDE=3.84e-03, BC=4.19e-04, DATA=1.58e-04, λ=4.3768
# Epoch 26500: Total Loss=7.34e-02, PDE=5.82e-03, BC=3.16e-04, DATA=1.49e-04, λ=4.3758
# Epoch 26600: Total Loss=2.47e-01, PDE=2.21e-02, BC=2.55e-04, DATA=2.59e-04, λ=4.3311
# Epoch 26700: Total Loss=4.46e-02, PDE=2.66e-03, BC=3.81e-04, DATA=1.76e-04, λ=4.3648
# Epoch 26800: Total Loss=7.81e-02, PDE=5.96e-03, BC=2.90e-04, DATA=1.83e-04, λ=4.3749
# Epoch 26900: Total Loss=5.51e-02, PDE=3.81e-03, BC=3.73e-04, DATA=1.66e-04, λ=4.3731
# Epoch 27000: Total Loss=5.74e-02, PDE=4.09e-03, BC=4.16e-04, DATA=1.61e-04, λ=4.3864
# Epoch 27100: Total Loss=6.45e-02, PDE=4.86e-03, BC=3.95e-04, DATA=1.55e-04, λ=4.3781
# Epoch 27200: Total Loss=8.92e-02, PDE=6.91e-03, BC=5.34e-04, DATA=1.96e-04, λ=4.3781
# Epoch 27300: Total Loss=1.14e-01, PDE=9.57e-03, BC=2.41e-04, DATA=1.85e-04, λ=4.3694
# Epoch 27400: Total Loss=6.64e-02, PDE=5.17e-03, BC=3.85e-04, DATA=1.43e-04, λ=4.3803
# Epoch 27500: Total Loss=7.40e-02, PDE=5.59e-03, BC=4.07e-04, DATA=1.77e-04, λ=4.3784
# Epoch 27600: Total Loss=6.28e-02, PDE=4.87e-03, BC=3.19e-04, DATA=1.38e-04, λ=4.3808
# Epoch 27700: Total Loss=4.84e-02, PDE=3.33e-03, BC=3.60e-04, DATA=1.48e-04, λ=4.3731
# Epoch 27800: Total Loss=5.85e-02, PDE=3.94e-03, BC=3.81e-04, DATA=1.87e-04, λ=4.3742
# Epoch 27900: Total Loss=5.05e-02, PDE=3.09e-03, BC=4.53e-04, DATA=1.92e-04, λ=4.3749
# Epoch 28000: Total Loss=6.31e-02, PDE=4.64e-03, BC=4.13e-04, DATA=1.62e-04, λ=4.3809
# Epoch 28100: Total Loss=4.29e-02, PDE=2.52e-03, BC=3.55e-04, DATA=1.74e-04, λ=4.3769
# Epoch 28200: Total Loss=2.73e-01, PDE=2.49e-02, BC=3.27e-04, DATA=2.44e-04, λ=4.3603
# Epoch 28300: Total Loss=6.13e-02, PDE=4.16e-03, BC=3.26e-04, DATA=1.94e-04, λ=4.3715
# Epoch 28400: Total Loss=4.54e-02, PDE=2.86e-03, BC=3.64e-04, DATA=1.64e-04, λ=4.3813
# Epoch 28500: Total Loss=5.20e-02, PDE=3.40e-03, BC=4.72e-04, DATA=1.75e-04, λ=4.3679
# Epoch 28600: Total Loss=5.01e-02, PDE=3.28e-03, BC=4.49e-04, DATA=1.68e-04, λ=4.3801
# Epoch 28700: Total Loss=4.35e-02, PDE=2.74e-03, BC=3.38e-04, DATA=1.58e-04, λ=4.3778
# Epoch 28800: Total Loss=6.46e-02, PDE=4.83e-03, BC=3.18e-04, DATA=1.60e-04, λ=4.3748
# Epoch 28900: Total Loss=6.02e-02, PDE=4.30e-03, BC=3.18e-04, DATA=1.69e-04, λ=4.3668
# Epoch 29000: Total Loss=3.82e-02, PDE=2.51e-03, BC=3.46e-04, DATA=1.28e-04, λ=4.3848
# Epoch 29100: Total Loss=5.49e-02, PDE=4.06e-03, BC=3.62e-04, DATA=1.39e-04, λ=4.3785
# Epoch 29200: Total Loss=1.38e-01, PDE=1.17e-02, BC=3.73e-04, DATA=2.03e-04, λ=4.3716
# Epoch 29300: Total Loss=7.27e-02, PDE=5.57e-03, BC=2.64e-04, DATA=1.67e-04, λ=4.3755
# Epoch 29400: Total Loss=6.63e-02, PDE=4.85e-03, BC=4.44e-04, DATA=1.74e-04, λ=4.3828
# Epoch 29500: Total Loss=1.03e-01, PDE=8.58e-03, BC=3.57e-04, DATA=1.69e-04, λ=4.3744
# Epoch 29600: Total Loss=5.02e-02, PDE=3.37e-03, BC=3.49e-04, DATA=1.62e-04, λ=4.3790
# Epoch 29700: Total Loss=1.42e-01, PDE=1.19e-02, BC=6.24e-04, DATA=2.22e-04, λ=4.3797
# Epoch 29800: Total Loss=4.76e-02, PDE=2.87e-03, BC=4.08e-04, DATA=1.85e-04, λ=4.3765
# Epoch 29900: Total Loss=6.12e-02, PDE=4.43e-03, BC=4.53e-04, DATA=1.64e-04, λ=4.3719

# %%
plot_axis(model)

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

def plot_slices(model, device, z0_list=(0.0, 0.3, 0.6)):
    """
    Compare u_pred vs. exact on:
      • several horizontal slices z = z0 (equatorial)
      • meridional slice (x=0 plane)
    """
    model.eval()
    all_u_resid = []  # For global vmax

    with torch.no_grad():
        # ---- Pass 1: compute residuals to find global vmax ----
        for z0 in z0_list:
            r_max = np.sqrt(max(1e-8, 1 - z0**2))
            theta = torch.linspace(0, 2*np.pi, 361, device=device)
            r = torch.linspace(0, r_max, 200, device=device)
            R, Θ = torch.meshgrid(r, theta, indexing='ij')
            X = R * torch.cos(Θ)
            Y = R * torch.sin(Θ)
            Z = torch.full_like(X, z0)
            pts_flat = torch.stack([X.reshape(-1), Y.reshape(-1), Z.reshape(-1)], 1)

            u_pred = model(pts_flat).reshape(R.shape).cpu().numpy()
            u_exact = exact_solution(pts_flat[:,0], pts_flat[:,1], pts_flat[:,2]).reshape(R.shape).cpu().numpy()
            u_resid = np.abs(u_pred - u_exact)
            all_u_resid.append(u_resid)

        global_vmax = max(np.max(r) for r in all_u_resid)
        vmin = 0.0

        # ---- Pass 2: plot each slice with consistent color range ----
        for i, z0 in enumerate(z0_list):
            r_max = np.sqrt(max(1e-8, 1 - z0**2))
            theta = torch.linspace(0, 2*np.pi, 361, device=device)
            r = torch.linspace(0, r_max, 200, device=device)
            R, Θ = torch.meshgrid(r, theta, indexing='ij')
            X = R * torch.cos(Θ)
            Y = R * torch.sin(Θ)
            Z = torch.full_like(X, z0)
            pts_flat = torch.stack([X.reshape(-1), Y.reshape(-1), Z.reshape(-1)], 1)

            u_pred = model(pts_flat).reshape(R.shape).cpu().numpy()
            u_exact = exact_solution(pts_flat[:,0], pts_flat[:,1], pts_flat[:,2]).reshape(R.shape).cpu().numpy()
            u_resid = all_u_resid[i]

            lambda_val = model.lambda_param.mean().item()

            fig, axs = plt.subplots(1, 3, subplot_kw={'projection': 'polar'}, figsize=(16, 4))
            # fig.suptitle(f'Equatorial Slice z={z0:.2f} | λ ≈ {lambda_val:.4f}', fontsize=12, y=1.1)
            for ax, data, ttl in zip(axs, [u_pred, u_exact, u_resid], ['Predicted Result', 'Exact Result', 'Error']):
                if ttl == 'Error':
                    c = ax.contourf(Θ.cpu(), R.cpu(), data, levels=50, cmap='jet', vmin=vmin, vmax=global_vmax)
                else:
                    c = ax.contourf(Θ.cpu(), R.cpu(), data, levels=50, cmap='jet')
                # ax.text(0.5, 1.12, ttl, transform=ax.transAxes, ha='center', va='center', fontsize=10)
                # fig.colorbar(c, ax=ax, shrink=0.8)
                fig.colorbar(c, ax=ax, shrink=0.9, pad=0.1)
                n_circles = 5
                tickvals = np.linspace(0, r_max, n_circles + 1)[1:]  # 5 circles, skip center
                ax.set_rticks(tickvals)
                ax.set_ylim(0, r_max)
                ax.set_yticklabels([f"{v:.1f}" for v in np.linspace(0.2, 1.0, n_circles)])

            plt.subplots_adjust(wspace=0.5)
            plt.tight_layout()
            plt.savefig(f'3D_z{z0:.2f}.png', dpi=400, bbox_inches='tight')

        # ---- Meridional slice x=0 (y–z plane) ----
        y = torch.linspace(-1, 1, 301, device=device)
        z = torch.linspace(-1, 1, 301, device=device)
        Y, Z = torch.meshgrid(y, z, indexing='ij')
        mask = Y**2 + Z**2 <= 1.0
        X0 = torch.zeros_like(Y)
        pts_plane = torch.stack([X0[mask], Y[mask], Z[mask]], 1)

        u_pred_plane = model(pts_plane).cpu().numpy()
        u_exact_plane = exact_solution(pts_plane[:,0], pts_plane[:,1], pts_plane[:,2]).cpu().numpy()

        U_pred_grid = np.full(Y.shape, np.nan)
        U_exact_grid = np.full_like(U_pred_grid, np.nan)
        U_pred_grid[mask.cpu().numpy()] = u_pred_plane
        U_exact_grid[mask.cpu().numpy()] = u_exact_plane

        # Compute abs error
        U_abs_error_grid = np.full_like(U_pred_grid, np.nan)
        U_abs_error_grid[mask.cpu().numpy()] = np.abs(u_pred_plane - u_exact_plane)


        common_min = np.nanmin([U_pred_grid, U_exact_grid])
        common_max = np.nanmax([U_pred_grid, U_exact_grid])
        error_max = np.nanmax(U_abs_error_grid)

        fig, axs = plt.subplots(1, 3, figsize=(16, 4))
        for ax, data, ttl in zip(axs, [U_pred_grid, U_exact_grid, U_abs_error_grid], ['Predicted Result', 'Exact Result', 'Error']):
            if ttl == 'Error':
                im = ax.imshow(data, origin='lower', extent=[-1, 1, -1, 1], cmap='jet', vmin=0, vmax=error_max)
            else:
                im = ax.imshow(data, origin='lower', extent=[-1, 1, -1, 1], cmap='jet', vmin=common_min, vmax=common_max)
            # ax.set_title(ttl)
            fig.colorbar(im, ax=ax, shrink=0.9, pad=0.1)
        plt.subplots_adjust(wspace=0.5)
        plt.tight_layout()
        plt.savefig('3D_meridional_slice_x0.png', dpi=400, bbox_inches='tight')
        plt.show()

# %%
plot_slices(model, model.device, z0_list=(0.0, 0.25, 0.5))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

sns.set(rc={'figure.figsize':(4, 4)})
sns.set_style("whitegrid")

samples = model.lambda_param.detach().cpu().numpy().flatten()
df = pd.DataFrame(samples, columns=['lambda_param'])

plt.figure(figsize=(5, 4))
sns.histplot(df['lambda_param'], kde=True, linewidth=2, edgecolor='blue', color='black', bins=30)
plt.xlabel('λ')
plt.ylabel('Count')
plt.title('Parameter Distribution')

# Set x-axis values to 2 decimal points
plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x:.3f}'))

plt.tight_layout()
plt.savefig('3D_histogram.png', dpi=400)
plt.show()

# %%
def plot_loss_history(model):
    epochs = range(len(model.loss_history))
    plt.figure(figsize=(8, 6))
    plt.plot(epochs, model.loss_history, label='Total Loss')
    plt.plot(epochs, model.li_history, label='PDE Loss')
    plt.plot(epochs, model.lb_history, label='BC Loss')
    plt.plot(epochs, model.ld_history, label='Data Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss Over Epochs')
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
    plt.tight_layout()
    plt.savefig('3D_loss.png', dpi=400)
    plt.show()

# %%
def plot_loss_history_log(model):
    epochs = range(len(model.loss_history))
    plt.figure(figsize=(8, 6))
    plt.semilogy(epochs, model.loss_history, label='Total Loss')
    plt.semilogy(epochs, model.li_history, label='PDE Loss')
    plt.semilogy(epochs, model.lb_history, label='BC Loss')
    plt.semilogy(epochs, model.ld_history, label='Data Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss (log scale)')
    plt.title('Loss Over Epochs (log scale)')
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
    plt.tight_layout()
    plt.savefig('3D_log_loss.png', dpi=400)
    plt.show()

# %%
plot_loss_history(model)

# %%
plot_loss_history_log(model)

# %%
def plot_axis(model):
    z = torch.linspace(-1,1,200,device=model.device)
    pts = torch.stack([torch.zeros_like(z), torch.zeros_like(z), z], dim=1)
    with torch.no_grad():
        u_pred = model(pts).cpu().numpy()
    z_np = z.cpu().numpy()
    u_ex = exact_solution(pts[:,0],pts[:,1],pts[:,2]).cpu().numpy()

    plt.figure(figsize=(5, 4))
    plt.plot(z_np, u_pred, label='Predicted')
    plt.plot(z_np, u_ex, '--', label='Exact')
    plt.legend()
    plt.xlabel('z')
    plt.ylabel('u')
    plt.title('Axis (x=y=0)')
    plt.tight_layout()
    plt.savefig('3D_Axis_plot.png', dpi=400)
    plt.show()

# %%
plot_axis(model)
